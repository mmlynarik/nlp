# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### Helper functions

# %%
def check_equal_ids(df1: pd.DataFrame, df2: pd.DataFrame) -> bool:
    if len(df1) != len(df2):
        return False
    df1 = df1["id"].sort_values().reset_index(drop=True)
    df2 = df2["id"].sort_values().reset_index(drop=True)
    return (df1 == df2).sum() == len(df1)

# %% [markdown]
# #### Load data from csv

# %%
features_df = pd.read_csv("features.csv", sep=";")
targets_df = pd.read_csv("targets.csv", sep=";")
text_features_df = pd.read_csv("text_features.csv", sep=";")

# %% [markdown]
# #### Check equal ids

# %% [markdown]
# Check if all three datasets represent the same observations

# %%
check_equal_ids(features_df, text_features_df), check_equal_ids(features_df, targets_df)
# Out:
# (True, True)

# %% [markdown]
# #### Merge data

# %% [markdown]
# We can now merge datasets on `id` column

# %%
data = pd.merge(features_df, text_features_df, on="id", how="inner").merge(targets_df, on="id", how="inner")
data
# Out:
#                                     id f_0    f_1    f_2     f_3     f_4  \
# 0     b03a97185bcd4e3297fffcbe7360c64d   F  0.495  0.400  1550.0  0.6445
# 1     84ab6aeda37c4943847d204c120410df   M  0.630  0.515  1550.0  1.2590
# 2     dcbb537ee552433780fde6dfb1d941c6   F  0.595  0.465  1550.0  1.0260
# 3     e9cc5c8b303045a783e11df15389cd39   M  0.360  0.295  1000.0  0.2105
# 4     bd8ca64a21fd4edeb3db59ce5db871bc   M  0.600  0.510  1850.0  1.2850
# ...                                ...  ..    ...    ...     ...     ...
# 4173  9af44122585b423493ba05828fba8ac3   M  0.645  0.485  1550.0  1.4890
# 4174  5ccd0a6c62c845838205fb184053294f   M  0.650  0.525  1850.0  1.6220
# 4175  f3290aaf37de4c74bf330e11cbe6bbd8   F  0.710  0.565  1950.0  1.6500
# 4176  b3facf6230fe4adf86b56f161be32725   M  0.595  0.455  1500.0  0.8860
# 4177  660421d0230d44bd8dcf53189f6eb7fb   I  0.465  0.355  1100.0  0.4740
#
#          f_5     f_6    f_7    f_8       f_9  \
# 0     0.2420  0.1325  0.205  SHORT  1.025113
# 1     0.4105  0.1970  0.410  SHORT  2.006427
# 2     0.4645  0.1120  0.305  SHORT  2.430176
# 3     0.0660  0.0525  0.075  SHORT  1.451025
# 4     0.6095  0.2745  0.315  SHORT  2.701401
# ...      ...     ...    ...    ...       ...
# 4173  0.5915  0.3120  0.380  SHORT  2.969376
# 4174  0.6645  0.3225  0.477   TALL  3.770031
# 4175  0.6380  0.3365  0.565   TALL  4.116161
# 4176  0.4315  0.2010  0.223  SHORT  3.177005
# 4177  0.2300  0.1005  0.120  SHORT  1.900401
#
#                                                    f_10  target
# 0     Measurable process selection theorem and non-a...       1
# 1                                                   NaN       1
# 2     On a topology property for moduli space of Kap...       0
# 3     Machine Learning on Sequential Data Using a Re...       0
# 4                   Multirole Logic (Extended Abstract)       0
# ...                                                 ...     ...
# 4173                                                NaN       1
# 4174  Recurrent Deterministic Policy Gradient Method...       0
# 4175        Multilink Communities of Multiplex Networks       1
# 4176  A geometric second-order-rectifiable stratific...       0
# 4177        Proactive Eavesdropping in Relaying Systems       0
#
# [4178 rows x 13 columns]

# %% [markdown]
# #### Train/test split

# %% [markdown]
# In order not to leak information from test data into training data, which would distort model evaluation metrics, we split data into train and test datasets before any exploratory analyses

# %%
train_dataset, test_dataset = train_test_split(data, test_size=0.2, random_state=100, stratify=data["target"])
train_dataset.shape, test_dataset.shape
# Out:
# ((3342, 13), (836, 13))

# %% [markdown]
# #### Input features

# %%
numeric_features = [f"f_{i}" for i in range(1, 10) if i != 8]
categorical_features = ["f_0", "f_8"]
text_features = ["f10"]
target = ["target"]

# %% [markdown]
# #### Outliers analysis

# %% [markdown]
# Before computing correlation and other outlier-sensitive analyses, we identify and fix the most critical outliers from numerical features. From the boxplots below, we can see the only feature that has outliers above or below `3*IQR` (double distance of inner fences displayed in boxplots) is `f_3`, so we only fix outliers for this variable by replacing them with the value of last observation not considered an outlier. The replacement value is calculated on train dataset and applied also to test dataset.

# %%
# Boxplots
rows, cols = 2, 4
fig = make_subplots(rows=rows, cols=cols)
for idx in range(rows * cols):
    feature = numeric_features[idx]
    fig.add_trace(go.Box(y=train_dataset[feature], name=feature), row=idx // cols + 1, col=idx % cols + 1)
fig.show()

# Replace outliers for f_3
train_dataset["f_3"] = np.minimum(train_dataset["f_3"], 2400)
test_dataset["f_3"] = np.minimum(test_dataset["f_3"], 2400)
# Out:
# <div>                            <div id="856a5a3c-46ab-4c8a-adb0-482a637925f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("856a5a3c-46ab-4c8a-adb0-482a637925f3")) {                    Plotly.newPlot(                        "856a5a3c-46ab-4c8a-adb0-482a637925f3",                        [{"name":"f_1","y":[0.7,0.65,0.61,0.595,0.605,0.45,0.615,0.695,0.395,0.375,0.675,0.62,0.425,0.65,0.56,0.625,0.6,0.57,0.53,0.55,0.63,0.45,0.33,0.585,0.495,0.395,0.45,0.42,0.555,0.36,0.385,0.59,0.5,0.5,0.625,0.525,0.655,0.585,0.58,0.545,0.6,0.645,0.5,0.495,0.375,0.53,0.52,0.56,0.665,0.65,0.47,0.565,0.615,0.575,0.555,0.355,0.49,0.435,0.6,0.5,0.685,0.405,0.45,0.675,0.57,0.65,0.6,0.43,0.57,0.41,0.235,0.745,0.535,0.55,0.575,0.455,0.475,0.63,0.375,0.48,0.55,0.275,0.67,0.55,0.4,0.695,0.475,0.315,0.465,0.61,0.565,0.705,0.23,0.49,0.58,0.61,0.45,0.26,0.63,0.33,0.625,0.645,0.42,0.645,0.415,0.525,0.535,0.4,0.635,0.71,0.28,0.72,0.53,0.34,0.525,0.67,0.525,0.25,0.67,0.665,0.47,0.61,0.505,0.64,0.58,0.63,0.63,0.7,0.59,0.445,0.575,0.505,0.615,0.66,0.37,0.52,0.505,0.53,0.54,0.575,0.4,0.515,0.695,0.435,0.45,0.515,0.515,0.455,0.6,0.3,0.505,0.655,0.475,0.395,0.64,0.565,0.505,0.455,0.61,0.455,0.55,0.31,0.43,0.635,0.555,0.58,0.57,0.505,0.62,0.2,0.485,0.525,0.215,0.65,0.655,0.585,0.29,0.69,0.455,0.535,0.535,0.62,0.55,0.56,0.505,0.335,0.315,0.535,0.625,0.695,0.53,0.135,0.57,0.375,0.5,0.61,0.65,0.4,0.42,0.395,0.68,0.56,0.47,0.24,0.635,0.585,0.61,0.41,0.495,0.58,0.49,0.65,0.55,0.57,0.44,0.58,0.48,0.63,0.535,0.475,0.515,0.375,0.62,0.385,0.5,0.405,0.63,0.585,0.535,0.595,0.68,0.39,0.645,0.41,0.525,0.595,0.295,0.305,0.46,0.4,0.555,0.535,0.62,0.51,0.35,0.455,0.59,0.325,0.655,0.57,0.625,0.525,0.415,0.63,0.45,0.595,0.225,0.64,0.665,0.555,0.61,0.245,0.505,0.565,0.425,0.675,0.445,0.48,0.7,0.49,0.52,0.65,0.66,0.655,0.585,0.405,0.295,0.69,0.46,0.74,0.37,0.35,0.545,0.415,0.645,0.595,0.37,0.565,0.705,0.56,0.395,0.405,0.415,0.41,0.525,0.52,0.4,0.58,0.515,0.475,0.58,0.355,0.475,0.465,0.565,0.495,0.45,0.585,0.75,0.27,0.435,0.655,0.55,0.6,0.655,0.56,0.48,0.415,0.355,0.51,0.455,0.45,0.475,0.63,0.66,0.5,0.305,0.505,0.61,0.375,0.595,0.405,0.55,0.595,0.295,0.5,0.58,0.615,0.39,0.665,0.64,0.64,0.6,0.375,0.39,0.695,0.3,0.165,0.39,0.42,0.735,0.29,0.555,0.55,0.575,0.525,0.56,0.635,0.645,0.29,0.625,0.72,0.69,0.35,0.605,0.56,0.535,0.38,0.455,0.645,0.58,0.67,0.74,0.625,0.665,0.615,0.605,0.32,0.43,0.545,0.58,0.77,0.525,0.455,0.4,0.6,0.755,0.54,0.15,0.37,0.33,0.63,0.72,0.385,0.485,0.42,0.625,0.58,0.53,0.375,0.48,0.555,0.5,0.605,0.53,0.57,0.615,0.58,0.51,0.675,0.56,0.815,0.54,0.7,0.66,0.57,0.67,0.645,0.58,0.45,0.51,0.635,0.45,0.315,0.605,0.285,0.29,0.265,0.345,0.65,0.45,0.445,0.615,0.605,0.36,0.215,0.595,0.55,0.53,0.665,0.455,0.56,0.655,0.45,0.58,0.555,0.67,0.535,0.245,0.535,0.525,0.535,0.545,0.55,0.585,0.61,0.53,0.345,0.53,0.495,0.31,0.695,0.63,0.315,0.54,0.76,0.67,0.46,0.56,0.68,0.175,0.62,0.335,0.35,0.61,0.68,0.405,0.46,0.46,0.52,0.605,0.655,0.535,0.585,0.595,0.205,0.545,0.59,0.385,0.505,0.655,0.45,0.405,0.515,0.25,0.565,0.455,0.62,0.41,0.435,0.58,0.525,0.585,0.685,0.595,0.555,0.575,0.465,0.52,0.64,0.33,0.485,0.51,0.72,0.31,0.44,0.595,0.515,0.45,0.43,0.655,0.475,0.57,0.67,0.65,0.55,0.57,0.485,0.54,0.42,0.495,0.365,0.66,0.605,0.555,0.55,0.62,0.405,0.515,0.48,0.625,0.685,0.48,0.41,0.56,0.375,0.535,0.625,0.59,0.61,0.185,0.52,0.605,0.585,0.155,0.385,0.64,0.44,0.46,0.605,0.49,0.63,0.7,0.615,0.6,0.58,0.67,0.5,0.55,0.57,0.275,0.555,0.35,0.33,0.575,0.495,0.54,0.35,0.445,0.58,0.605,0.605,0.395,0.515,0.47,0.71,0.56,0.32,0.53,0.41,0.42,0.63,0.615,0.365,0.72,0.425,0.59,0.625,0.595,0.665,0.32,0.555,0.51,0.65,0.515,0.4,0.375,0.685,0.635,0.615,0.175,0.65,0.69,0.295,0.505,0.62,0.685,0.565,0.13,0.65,0.44,0.67,0.77,0.61,0.58,0.6,0.46,0.625,0.415,0.24,0.63,0.72,0.53,0.385,0.52,0.64, ...

# %% [markdown]
# #### Correlation analysis of inputs

# %% [markdown]
# We see that all numerical featurs are strongly positively correlated with some having nearly perfect correlation.

# %%
corr = train_dataset[numeric_features].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_9c9bb_row0_col0, #T_9c9bb_row1_col1, #T_9c9bb_row2_col2, #T_9c9bb_row3_col3, #T_9c9bb_row4_col4, #T_9c9bb_row5_col5, #T_9c9bb_row6_col6, #T_9c9bb_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9c9bb_row0_col1, #T_9c9bb_row1_col0 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_9c9bb_row0_col2, #T_9c9bb_row1_col3 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_9c9bb_row0_col3, #T_9c9bb_row1_col6, #T_9c9bb_row5_col6 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_9c9bb_row0_col4, #T_9c9bb_row1_col5 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_9c9bb_row0_col5, #T_9c9bb_row0_col6, #T_9c9bb_row2_col1, #T_9c9bb_row3_col0, #T_9c9bb_row3_col1 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_9c9bb_row0_col7 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_9c9bb_row1_col2 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_9c9bb_row1_col4, #T_9c9bb_row6_col0 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_9c9bb_row1_col7 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_9c9bb_row2_col0, #T_9c9bb_row5_col1 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_9c9bb_row2_col3 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_9c9bb_row2_col4 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_9c9bb_row2_col5 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_9c9bb_row2_col6, #T_9c9bb_row4_col0 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_9c9bb_row2_col7, #T_9c9bb_row7_col0, #T_9c9bb_row7_col1, #T_9c9bb_row7_col2, #T_9c9bb_row7_col3, #T_9c9bb_row7_col4, #T_9c9bb_row7_col5, #T_9c9bb_row7_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9c9bb_row3_col2 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_9c9bb_row3_col4, #T_9c9bb_row4_col3 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_9c9bb_row3_col5 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_9c9bb_row3_col6 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_9c9bb_row3_col7 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_9c9bb_row4_col1, #T_9c9bb_row6_col4 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_9c9bb_row4_col2 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_9c9bb_row4_col5 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_9c9bb_row4_col6 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_9c9bb_row4_col7 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_9c9bb_row5_col0 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_9c9bb_row5_col2 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_9c9bb_row5_col3 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_9c9bb_row5_col4 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_9c9bb_row5_col7 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_9c9bb_row6_col1 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_9c9bb_row6_col2 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_9c9bb_row6_col3 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_9c9bb_row6_col5 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_9c9bb_row6_col7 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9c9bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c9bb_level0_col0" class="col_heading level0 col0" >f_1</th>
#       <th id="T_9c9bb_level0_col1" class="col_heading level0 col1" >f_2</th>
#       <th id="T_9c9bb_level0_col2" class="col_heading level0 col2" >f_3</th>
#       <th id="T_9c9bb_level0_col3" class="col_heading level0 col3" >f_4</th>
#       <th id="T_9c9bb_level0_col4" class="col_heading level0 col4" >f_5</th>
#       <th id="T_9c9bb_level0_col5" class="col_heading level0 col5" >f_6</th>
#       <th id="T_9c9bb_level0_col6" class="col_heading level0 col6" >f_7</th>
#       <th id="T_9c9bb_level0_col7" class="col_heading level0 col7" >f_9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c9bb_level0_row0" class="row_heading level0 row0" >f_1</th>
#       <td id="T_9c9bb_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_9c9bb_row0_col1" class="data row0 col1" >0.987980</td>
#       <td id="T_9c9bb_row0_col2" class="data row0 col2" >0.901430</td>
#       <td id="T_9c9bb_row0_col3" class="data row0 col3" >0.908338</td>
#       <td id="T_9c9bb_row0_col4" class="data row0 col4" >0.897018</td>
#       <td id="T_9c9bb_row0_col5" class="data row0 col5" >0.905446</td>
#       <td id="T_9c9bb_row0_col6" class="data row0 col6" >0.899032</td>
#       <td id="T_9c9bb_row0_col7" class="data row0 col7" >0.650757</td>
#     </tr>
#     <tr>
#       <th id="T_9c9bb_level0_row1" class="row_heading level0 row1" >f_2</th>
#       <td id="T_9c9bb_row1_col0" class="data row1 col0" >0.987980</td>
#       <td id="T_9c9bb_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_9c9bb_row1_col2" class="data row1 col2" >0.909232</td>
#       <td id="T_9c9bb_row1_col3" class="data row1 col3" >0.908021</td>
#       <td id="T_9c9bb_row1_col4" class="data row1 col4" >0.891577</td>
#       <td id="T_9c9bb_row1_col5" class="data row1 col5" >0.902056</td>
#       <td id="T_9c9bb_row1_col6" class="data row1 col6" >0.906983</td>
#       <td id="T_9c9bb_row1_col7" class="data row1 col7" >0.653372</td>
#     </tr>
#     <tr>
#       <th id="T_9c9bb_level0_row2" class="row_heading level0 row2" >f_3</th>
#       <td id="T_9c9bb_row2_col0" class="data row2 col0" >0.901430</td>
#       <td id="T_9c9bb_row2_col1" class="data row2 col1" >0.909232</td>
#       <td id="T_9c9bb_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_9c9bb_row2_col3" class="data row2 col3" >0.867424</td>
#       <td id="T_9c9bb_row2_col4" class="data row2 col4" >0.833317</td>
#       <td id="T_9c9bb_row2_col5" class="data row2 col5" >0.862582</td>
#       <td id="T_9c9bb_row2_col6" class="data row2 col6" >0.887836</td>
#       <td id="T_9c9bb_row2_col7" class="data row2 col7" >0.600238</td>
#     </tr>
#     <tr>
#       <th id="T_9c9bb_level0_row3" class="row_heading level0 row3" >f_4</th>
#       <td id="T_9c9bb_row3_col0" class="data row3 col0" >0.908338</td>
#       <td id="T_9c9bb_row3_col1" class="data row3 col1" >0.908021</td>
#       <td id="T_9c9bb_row3_col2" class="data row3 col2" >0.867424</td>
#       <td id="T_9c9bb_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_9c9bb_row3_col4" class="data row3 col4" >0.941120</td>
#       <td id="T_9c9bb_row3_col5" class="data row3 col5" >0.942675</td>
#       <td id="T_9c9bb_row3_col6" class="data row3 col6" >0.932871</td>
#       <td id="T_9c9bb_row3_col7" class="data row3 col7" >0.627132</td>
#     </tr>
#     <tr>
#       <th id="T_9c9bb_level0_row4" class="row_heading level0 row4" >f_5</th>
#       <td id="T_9c9bb_row4_col0" class="data row4 col0" >0.897018</td>
#       <td id="T_9c9bb_row4_col1" class="data row4 col1" >0.891577</td>
#       <td id="T_9c9bb_row4_col2" class="data row4 col2" >0.833317</td>
#       <td id="T_9c9bb_row4_col3" class="data row4 col3" >0.941120</td>
#       <td id="T_9c9bb_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_9c9bb_row4_col5" class="data row4 col5" >0.930115</td>
#       <td id="T_9c9bb_row4_col6" class="data row4 col6" >0.882316</td>
#       <td id="T_9c9bb_row4_col7" class="data row4 col7" >0.625964</td>
#     </tr>
#     <tr>
#       <th id="T_9c9bb_level0_row5" class="row_heading level0 row5" >f_6</th>
#       <td id="T_9c9bb_row5_col0" class="data row5 col0" >0.905446</td>
#       <td id="T_9c9bb_row5_col1" class="data row5 col1" >0.902056</td>
#       <td id="T_9c9bb_row5_col2" class="data row5 col2" >0.862582</td>
#       <td id="T_9c9bb_row5_col3" class="data row5 col3" >0.942675</td>
#       <td id="T_9c9bb_row5_col4" class="data row5 col4" >0.930115</td>
#       <td id="T_9c9bb_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_9c9bb_row5_col6" class="data row5 col6" >0.907169</td>
#       <td id="T_9c9bb_row5_col7" class="data row5 col7" >0.642268</td>
#     </tr>
#     <tr>
#       <th id="T_9c9bb_level0_row6" class="row_heading level0 row6" >f_7</th>
#       <td id="T_9c9bb_row6_col0" class="data row6 col0" >0.899032</td>
#       <td id="T

# %% [markdown]
# #### Null values analysis

# %% [markdown]
# We see that `f_2` and `f_10` are the two features with most null values (`~10%` of dataset samples). Since the `f_2` is nearly identical to `f_1` based on the correlation analysis, we can exlude it and solve its null value problem. Since we don't know more details about the null values in `f_0` variable and the number of affected observations is not high, we will discard the observations for which `f_0` is null.

# %%
display(pd.DataFrame(train_dataset.isna().sum()).T)
numeric_features.remove("f_2")

train_dataset = train_dataset[~train_dataset["f_0"].isna()]
test_dataset = test_dataset[~test_dataset["f_0"].isna()]
# Out:
#    id  f_0  f_1  f_2  f_3  f_4  f_5  f_6  f_7  f_8  f_9  f_10  target
# 0   0   55    1  331    1    1    1    1    1    1    1   386       0

# %% [markdown]
# #### Categorical features

# %% [markdown]
# Distribution of values in categorical features is as follows. We can see that the number of observations in M, F, I categories is roughly the same (we assume they represent category of papers from math, physics and informatics).

# %%
display(train_dataset[categorical_features[0]].value_counts())
train_dataset[categorical_features[1]].value_counts()
# Out:
# f_0
# M    1195
# F    1049
# I    1043
# Name: count, dtype: int64
# f_8
# SHORT    2970
# TALL      317
# Name: count, dtype: int64

# %% [markdown]
# #### [Classical] Train dataset with non-null features without most critical outliers and most correlated numerical feature

# %%
train_dataset = train_dataset[numeric_features + categorical_features + target]
train_dataset
# Out:
#         f_1     f_3     f_4     f_5     f_6    f_7       f_9 f_0    f_8  \
# 1882  0.700  2150.0  1.9780  0.6675  0.3125  0.710  3.190625   F   TALL
# 4019  0.650  1900.0  1.9500  0.6265  0.4005  0.395  3.241601   M  SHORT
# 2784  0.595  1400.0  0.8520  0.4215  0.2255  0.227  2.583401   M  SHORT
# 3078  0.605  1450.0  0.8840  0.3835  0.1905  0.270  2.565161   M  SHORT
# 3374  0.450  1000.0  0.4110  0.1945  0.1000  0.098  1.840000   I  SHORT
# ...     ...     ...     ...     ...     ...    ...       ...  ..    ...
# 684   0.350  1100.0  0.2090  0.0660  0.0590  0.075  1.767405   I  SHORT
# 2114  0.660  2000.0  1.6760  0.6730  0.4805  0.450  3.563521   F   TALL
# 3722  0.295   700.0  0.1365  0.0575  0.0295  0.035  0.887611   I  SHORT
# 1129  0.465  1200.0  0.5805  0.2550  0.0915  0.184  2.366861   I  SHORT
# 121   0.575  1850.0  1.1560  0.5525  0.2430  0.295  3.170245   M  SHORT
#
#       target
# 1882       1
# 4019       1
# 2784       0
# 3078       0
# 3374       0
# ...      ...
# 684        0
# 2114       1
# 3722       0
# 1129       0
# 121        1
#
# [3287 rows x 10 columns]

# %%
test_dataset = test_dataset[numeric_features + categorical_features + target]
test_dataset
# Out:
#         f_1     f_3     f_4     f_5     f_6     f_7       f_9 f_0    f_8  \
# 2534  0.615  1550.0  1.1375  0.3670  0.2360  0.3700  3.353480   M  SHORT
# 3391  0.350   900.0  0.1980  0.0725  0.0560  0.0600  1.059408   M  SHORT
# 4103  0.555  1450.0  0.8500  0.4165  0.1685  0.2300  1.166784   M  SHORT
# 2185  0.575  1350.0  0.8570  0.4610  0.1470  0.2125  2.983045   F  SHORT
# 3802  0.595  1800.0  1.0530  0.4405  0.1920  0.3900  1.263728   F  SHORT
# ...     ...     ...     ...     ...     ...     ...       ...  ..    ...
# 3489  0.485  1000.0  0.5130  0.2190  0.1075  0.1300  2.482781   I  SHORT
# 1593  0.485  1200.0  0.5155  0.2465  0.1025  0.1470  0.991012   I  SHORT
# 2946  0.270   700.0  0.1060  0.0465  0.0180  0.0360  0.540648   M  SHORT
# 2575  0.370   950.0  0.2655  0.1220  0.0520  0.0800  1.863520   I  SHORT
# 3401  0.185  1200.0  0.4645  0.1960  0.1045  0.1500  0.587761   I  SHORT
#
#       target
# 2534       1
# 3391       0
# 4103       0
# 2185       0
# 3802       1
# ...      ...
# 3489       0
# 1593       0
# 2946       0
# 2575       0
# 3401       0
#
# [823 rows x 10 columns]
