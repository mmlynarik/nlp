# %%
import pandas as pd
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %% [markdown]
# #### Helper functions

# %%
def check_equal_ids(df1: pd.DataFrame, df2: pd.DataFrame) -> bool:
    if len(df1) != len(df2):
        return False
    df1 = df1["id"].sort_values().reset_index(drop=True)
    df2 = df2["id"].sort_values().reset_index(drop=True)
    return (df1 == df2).sum() == len(df1)

# %% [markdown]
# #### Load data from csv

# %%
features_df = pd.read_csv("features.csv", sep=";")
targets_df = pd.read_csv("targets.csv", sep=";")
text_features_df = pd.read_csv("text_features.csv", sep=";")

# %% [markdown]
# #### Check equal ids

# %% [markdown]
# Check if all three datasets represent the same observations

# %%
check_equal_ids(features_df, text_features_df), check_equal_ids(features_df, targets_df)
# Out:
# (True, True)

# %% [markdown]
# #### Merge data

# %% [markdown]
# We can now merge datasets on `id` column

# %%
data = pd.merge(features_df, targets_df, on="id", how="inner").merge(text_features_df, on="id", how="inner")
data
# Out:
#                                     id f_0    f_1    f_2     f_3     f_4  \
# 0     b03a97185bcd4e3297fffcbe7360c64d   F  0.495  0.400  1550.0  0.6445
# 1     84ab6aeda37c4943847d204c120410df   M  0.630  0.515  1550.0  1.2590
# 2     dcbb537ee552433780fde6dfb1d941c6   F  0.595  0.465  1550.0  1.0260
# 3     e9cc5c8b303045a783e11df15389cd39   M  0.360  0.295  1000.0  0.2105
# 4     bd8ca64a21fd4edeb3db59ce5db871bc   M  0.600  0.510  1850.0  1.2850
# ...                                ...  ..    ...    ...     ...     ...
# 4173  9af44122585b423493ba05828fba8ac3   M  0.645  0.485  1550.0  1.4890
# 4174  5ccd0a6c62c845838205fb184053294f   M  0.650  0.525  1850.0  1.6220
# 4175  f3290aaf37de4c74bf330e11cbe6bbd8   F  0.710  0.565  1950.0  1.6500
# 4176  b3facf6230fe4adf86b56f161be32725   M  0.595  0.455  1500.0  0.8860
# 4177  660421d0230d44bd8dcf53189f6eb7fb   I  0.465  0.355  1100.0  0.4740
#
#          f_5     f_6    f_7    f_8       f_9  target  \
# 0     0.2420  0.1325  0.205  SHORT  1.025113       1
# 1     0.4105  0.1970  0.410  SHORT  2.006427       1
# 2     0.4645  0.1120  0.305  SHORT  2.430176       0
# 3     0.0660  0.0525  0.075  SHORT  1.451025       0
# 4     0.6095  0.2745  0.315  SHORT  2.701401       0
# ...      ...     ...    ...    ...       ...     ...
# 4173  0.5915  0.3120  0.380  SHORT  2.969376       1
# 4174  0.6645  0.3225  0.477   TALL  3.770031       0
# 4175  0.6380  0.3365  0.565   TALL  4.116161       1
# 4176  0.4315  0.2010  0.223  SHORT  3.177005       0
# 4177  0.2300  0.1005  0.120  SHORT  1.900401       0
#
#                                                    f_10
# 0     Measurable process selection theorem and non-a...
# 1                                                   NaN
# 2     On a topology property for moduli space of Kap...
# 3     Machine Learning on Sequential Data Using a Re...
# 4                   Multirole Logic (Extended Abstract)
# ...                                                 ...
# 4173                                                NaN
# 4174  Recurrent Deterministic Policy Gradient Method...
# 4175        Multilink Communities of Multiplex Networks
# 4176  A geometric second-order-rectifiable stratific...
# 4177        Proactive Eavesdropping in Relaying Systems
#
# [4178 rows x 13 columns]

# %% [markdown]
# #### Input features

# %%
numeric_features = [f"f_{i}" for i in range(1, 10) if i != 8]
categorical_features = ["f_0", "f_8"]
text_features = ["f10"]

# %% [markdown]
# #### Outliers analysis

# %% [markdown]
# Before computing correlation and other outlier-sensitive analyses, we identify and remove most critical outliers from numerical features. From the boxplots below, we can see the only feature that has outliers above or below `3*IQR` (double distance of inner fences displayed in boxplots) is `f_3`, so we only remove outliers for this variable

# %%
# Boxplots
rows, cols = 2, 4
fig = make_subplots(rows=rows, cols=cols)
for idx in range(rows * cols):
    feature = numeric_features[idx]
    fig.add_trace(go.Box(y=data[feature], name=feature), row=idx // cols + 1, col=idx % cols + 1)
fig.show()

# Filter outliers for f_3
data = data[data["f_3"] < 3000]
# Out:
# <div>                            <div id="b74c231b-e94e-4469-beec-fe373b10d1e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b74c231b-e94e-4469-beec-fe373b10d1e2")) {                    Plotly.newPlot(                        "b74c231b-e94e-4469-beec-fe373b10d1e2",                        [{"name":"f_1","y":[0.495,0.63,0.595,0.36,0.6,0.47,0.56,0.325,0.52,0.395,0.235,0.56,0.655,0.57,0.71,0.61,0.33,0.355,0.235,0.56,0.6,0.545,0.72,0.37,0.53,0.465,0.535,0.745,0.61,0.555,0.58,0.61,0.405,0.62,0.585,0.575,0.67,0.625,0.54,0.67,0.605,0.42,0.385,0.45,0.67,0.455,0.475,0.51,0.5,0.705,0.32,0.235,0.44,0.42,0.395,0.44,0.675,0.33,0.36,0.655,0.37,0.6,0.45,0.6,0.465,0.545,0.41,0.435,0.555,0.38,0.385,0.4,0.655,0.505,0.45,0.455,0.43,0.615,0.67,0.57,0.435,0.35,0.72,0.445,0.47,0.55,0.69,0.5,0.44,0.535,0.375,0.485,0.615,0.575,0.68,0.575,0.585,0.325,0.645,0.285,0.62,0.57,0.595,0.255,0.675,0.35,0.61,0.53,0.435,0.59,0.395,0.365,0.49,0.6,0.52,0.73,0.685,0.5,0.5,0.575,0.45,0.575,0.55,0.645,0.37,0.55,0.41,0.625,0.695,0.63,0.55,0.58,0.465,0.65,0.5,0.69,0.645,0.37,0.525,0.415,0.66,0.29,0.395,0.33,0.305,0.385,0.645,0.635,0.19,0.595,0.645,0.69,0.565,0.705,0.63,0.45,0.575,0.635,0.155,0.565,0.575,0.57,0.495,0.755,0.74,0.475,0.595,0.705,0.415,0.575,0.775,0.655,0.515,0.53,0.63,0.55,0.48,0.725,0.13,0.435,0.615,0.335,0.725,0.45,0.59,0.44,0.65,0.635,0.35,0.35,0.44,0.48,0.525,0.5,0.495,0.64,0.6,0.5,0.375,0.6,0.735,0.53,0.59,0.445,0.615,0.525,0.39,0.555,0.445,0.37,0.485,0.53,0.13,0.4,0.375,0.565,0.48,0.535,0.325,0.255,0.52,0.515,0.325,0.665,0.37,0.37,0.595,0.66,0.53,0.565,0.2,0.64,0.56,0.575,0.635,0.615,0.5,0.58,0.225,0.6,0.385,0.32,0.62,0.585,0.715,0.35,0.58,0.39,0.58,0.64,0.625,0.45,0.555,0.455,0.655,0.655,0.415,0.65,0.49,0.51,0.37,0.655,0.665,0.655,0.505,0.615,0.57,0.48,0.495,0.34,0.525,0.555,0.465,0.635,0.55,0.51,0.24,0.665,0.585,0.585,0.
row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a3ff1_row0_col1, #T_a3ff1_row1_col0 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_a3ff1_row0_col2 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_a3ff1_row0_col3, #T_a3ff1_row1_col3, #T_a3ff1_row1_col6 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_a3ff1_row0_col4, #T_a3ff1_row2_col6 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_a3ff1_row0_col5, #T_a3ff1_row0_col6, #T_a3ff1_row3_col0 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_a3ff1_row0_col7, #T_a3ff1_row1_col7 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_a3ff1_row1_col2 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_a3ff1_row1_col4, #T_a3ff1_row6_col0 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_a3ff1_row1_col5 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_a3ff1_row2_col0, #T_a3ff1_row5_col1 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_a3ff1_row2_col1, #T_a3ff1_row3_col1 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_a3ff1_row2_col3 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_a3ff1_row2_col4 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_a3ff1_row2_col5 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_a3ff1_row2_col7, #T_a3ff1_row7_col0, #T_a3ff1_row7_col1, #T_a3ff1_row7_col2, #T_a3ff1_row7_col3, #T_a3ff1_row7_col4, #T_a3ff1_row7_col5, #T_a3ff1_row7_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a3ff1_row3_col2, #T_a3ff1_row4_col6 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_a3ff1_row3_col4 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_a3ff1_row3_col5 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_a3ff1_row3_col6, #T_a3ff1_row6_col3 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_a3ff1_row3_col7 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_a3ff1_row4_col0 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_a3ff1_row4_col1, #T_a3ff1_row6_col4 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_a3ff1_row4_col2 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_a3ff1_row4_col3 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_a3ff1_row4_col5 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_a3ff1_row4_col7 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_a3ff1_row5_col0, #T_a3ff1_row6_col2 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_a3ff1_row5_col2 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_a3ff1_row5_col3 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_a3ff1_row5_col4 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_a3ff1_row5_col6 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_a3ff1_row5_col7 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_a3ff1_row6_col1 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_a3ff1_row6_col5 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_a3ff1_row6_col7 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a3ff1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3ff1_level0_col0" class="col_heading level0 col0" >f_1</th>
#       <th id="T_a3ff1_level0_col1" class="col_heading level0 col1" >f_2</th>
#       <th id="T_a3ff1_level0_col2" class="col_heading level0 col2" >f_3</th>
#       <th id="T_a3ff1_level0_col3" class="col_heading level0 col3" >f_4</th>
#       <th id="T_a3ff1_level0_col4" class="col_heading level0 col4" >f_5</th>
#       <th id="T_a3ff1_level0_col5" class="col_heading level0 col5" >f_6</th>
#       <th id="T_a3ff1_level0_col6" class="col_heading level0 col6" >f_7</th>
#       <th id="T_a3ff1_level0_col7" class="col_heading level0 col7" >f_9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3ff1_level0_row0" class="row_heading level0 row0" >f_1</th>
#       <td id="T_a3ff1_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a3ff1_row0_col1" class="data row0 col1" >0.987128</td>
#       <td id="T_a3ff1_row0_col2" class="data row0 col2" >0.899834</td>
#       <td id="T_a3ff1_row0_col3" class="data row0 col3" >0.907389</td>
#       <td id="T_a3ff1_row0_col4" class="data row0 col4" >0.888886</td>
#       <td id="T_a3ff1_row0_col5" class="data row0 col5" >0.903091</td>
#       <td id="T_a3ff1_row0_col6" class="data row0 col6" >0.897648</td>
#       <td id="T_a3ff1_row0_col7" class="data row0 col7" >0.646238</td>
#     </tr>
#     <tr>
#       <th id="T_a3ff1_level0_row1" class="row_heading level0 row1" >f_2</th>
#       <td id="T_a3ff1_row1_col0" class="data row1 col0" >0.987128</td>
#       <td id="T_a3ff1_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a3ff1_row1_col2" class="data row1 col2" >0.907436</td>
#       <td id="T_a3ff1_row1_col3" class="data row1 col3" >0.907612</td>
#       <td id="T_a3ff1_row1_col4" class="data row1 col4" >0.887198</td>
#       <td id="T_a3ff1_row1_col5" class="data row1 col5" >0.900211</td>
#       <td id="T_a3ff1_row1_col6" class="data row1 col6" >0.905408</td>
#       <td id="T_a3ff1_row1_col7" class="data row1 col7" >0.646300</td>
#     </tr>
#     <tr>
#       <th id="T_a3ff1_level0_row2" class="row_heading level0 row2" >f_3</th>
#       <td id="T_a3ff1_row2_col0" class="data row2 col0" >0.899834</td>
#       <td id="T_a3ff1_row2_col1" class="data row2 col1" >0.907436</td>
#       <td id="T_a3ff1_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_a3ff1_row2_col3" class="data row2 col3" >0.870132</td>
#       <td id="T_a3ff1_row2_col4" class="data row2 col4" >0.828963</td>
#       <td id="T_a3ff1_row2_col5" class="data row2 col5" >0.865710</td>
#       <td id="T_a3ff1_row2_col6" class="data row2 col6" >0.888980</td>
#       <td id="T_a3ff1_row2_col7" class="data row2 col7" >0.594742</td>
#     </tr>
#     <tr>
#       <th id="T_a3ff1_level0_row3" class="row_heading level0 row3" >f_4</th>
#       <td id="T_a3ff1_row3_col0" class="data row3 col0" >0.907389</td>
#       <td id="T_a3ff1_row3_col1" class="data row3 col1" >0.907612</td>
#       <td id="T_a3ff1_row3_col2" class="data row3 col2" >0.870132</td>
#       <td id="T_a3ff1_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_a3ff1_row3_col4" class="data row3 col4" >0.937176</td>
#       <td id="T_a3ff1_row3_col5" class="data row3 col5" >0.941768</td>
#       <td id="T_a3ff1_row3_col6" class="data row3 col6" >0.933583</td>
#       <td id="T_a3ff1_row3_col7" class="data row3 col7" >0.620254</td>
#     </tr>
#     <tr>
#       <th id="T_a3ff1_level0_row4" class="row_heading level0 row4" >f_5</th>
#       <td id="T_a3ff1_row4_col0" class="data row4 col0" >0.888886</td>
#       <td id="T_a3ff1_row4_col1" class="data row4 col1" >0.887198</td>
#       <td id="T_a3ff1_row4_col2" class="data row4 col2" >0.828963</td>
#       <td id="T_a3ff1_row4_col3" class="data row4 col3" >0.937176</td>
#       <td id="T_a3ff1_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_a3ff1_row4_col5" class="data row4 col5" >0.925323</td>
#       <td id="T_a3ff1_row4_col6" class="data row4 col6" >0.875920</td>
#       <td id="T_a3ff1_row4_col7" class="data row4 col7" >0.610852</td>
#     </tr>
#     <tr>
#       <th id="T_a3ff1_level0_row5" class="row_heading level0 row5" >f_6</th>
#       <td id="T_a3ff1_row5_col0" class="data row5 col0" >0.903091</td>
#       <td id="T_a3ff1_row5_col1" class="data row5 col1" >0.900211</td>
#       <td id="T_a3ff1_row5_col2" class="data row5 col2" >0.865710</td>
#       <td id="T_a3ff1_row5_col3" class="data row5 col3" >0.941768</td>
#       <td id="T_a3ff1_row5_col4" class="data row5 col4" >0.925323</td>
#       <td id="T_a3ff1_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_a3ff1_row5_col6" class="data row5 col6" >0.907603</td>
#       <td id="T_a3ff1_row5_col7" class="data row5 col7" >0.632607</td>
#     </tr>
#     <tr>
#       <th id="T_a3ff1_level0_row6" class="row_heading level0 row6" >f_7</th>
#       <td id="T_a3ff1_row6_col0" class="data row6 col0" >0.897648</td>
#       <td id="T

# %% [markdown]
# #### Null values analysis

# %% [markdown]
# We see that `f_2` and `f_10` are the two features with most null values (`~10%` of dataset samples). Since the `f_2` is nearly identical to `f_1`, we can exlude it and solve its null value problem.

# %%
display(pd.DataFrame(data.isna().sum()).T)
numeric_features.remove("f_2")
# Out:
#    id  f_0  f_1  f_2  f_3  f_4  f_5  f_6  f_7  f_8  f_9  target  f_10
# 0   0   67    0  412    0    0    0    0    0    0    0       0   467

# %%
# Out:
# ['f_1', 'f_3', 'f_4', 'f_5', 'f_6', 'f_7', 'f_9']
