# %%
from datetime import date

import pandas as pd

from topicmodel.datamodule import OKRADataModule
from topicmodel.utils import text_to_sentences

# %%
datamodule = OKRADataModule(date_from=date(2011, 1, 1), date_to=date(2019, 1, 1))
datamodule.prepare_data()
df_okra = datamodule.setup()

# %%
text_to_sentences(df_okra["text"][24])
df_okra
# Out:
#         id                       date  \
# 0     2804  2017-06-07 17:40:31+00:00
# 1     3902  2018-07-17 09:32:06+00:00
# 2     2093  2018-07-16 21:01:22+00:00
# 3     2197  2018-07-05 18:15:30+00:00
# 4     2681  2018-06-30 10:48:30+00:00
# ...    ...                        ...
# 2016  4038  2017-07-06 20:20:58+00:00
# 2017  4039  2016-11-29 10:26:41+00:00
# 2018  4040  2016-07-17 07:42:11+00:00
# 2019  4041  2016-05-22 12:25:51+00:00
# 2020  4042  2015-10-21 14:12:51+00:00
#
#                                                   title  \
# 0                                                 Hello
# 1                   No stars would be more appropriate.
# 2                 Isn't possible to review them with 0…
# 3                                  A total nightmare!!!
# 4                 dire And disgusting joke of a service
# ...                                                 ...
# 2016                                               Late
# 2017             Not sure why they even have timetables
# 2018                                     Helpful guards
# 2019                   Often late but clean and decent.
# 2020  Train service has improved, but customer servi...
#
#                                                    text  \
# 0                                                 Hello
# 1                   No stars would be more appropriate.
# 2          Isn't possible to review them with 0 stars?!
# 3     The most disgraceful, useless and totally inco...
# 4                   I don’t want to give a star at all.
# ...                                                 ...
# 2016  Late, cancelled, signal failures, too much rai...
# 2017  Trains are constantly delayed or cancelled. I ...
# 2018  On a yearly basis we take a group of Preschool...
# 2019  I travel by them every day. I like their newis...
# 2020                       To start with the positives:
#
#                                                     url  \
# 0     https://uk.trustpilot.com/review/www.virgintra...
# 1          https://uk.trustpilot.com/review/www.gwr.com
# 2     https://uk.trustpilot.com/review/www.nationalr...
# 3     https://uk.trustpilot.com/review/www.nationalr...
# 4     https://uk.trustpilot.com/review/www.nationalr...
# ...                                                 ...
# 2016  https://uk.trustpilot.com/review/www.southeast...
# 2017  https://uk.trustpilot.com/review/www.southeast...
# 2018  https://uk.trustpilot.com/review/www.southeast...
# 2019  https://uk.trustpilot.com/review/www.southeast...
# 2020  https://uk.trustpilot.com/review/www.southeast...
#
#                                               stars  \
# 0     star-rating star-rating-1 star-rating--medium
# 1     star-rating star-rating-1 star-rating--medium
# 2     star-rating star-rating-1 star-rating--medium
# 3     star-rating star-rating-1 star-rating--medium
# 4     star-rating star-rating-1 star-rating--medium
# ...                                             ...
# 2016  star-rating star-rating-1 star-rating--medium
# 2017  star-rating star-rating-1 star-rating--medium
# 2018  star-rating star-rating-5 star-rating--medium
# 2019  star-rating star-rating-3 star-rating--medium
# 2020  star-rating star-rating-2 star-rating--medium
#
#                                                     raw
# 0     {'url': 'https://uk.trustpilot.com/review/www....
# 1     {'url': 'https://uk.trustpilot.com/review/www....
# 2     {'url': 'https://uk.trustpilot.com/review/www....
# 3     {'url': 'https://uk.trustpilot.com/review/www....
# 4     {'url': 'https://uk.trustpilot.com/review/www....
# ...                                                 ...
# 2016  {'url': 'https://uk.trustpilot.com/review/www....
# 2017  {'url': 'https://uk.trustpilot.com/review/www....
# 2018  {'url': 'https://uk.trustpilot.com/review/www....
# 2019  {'url': 'https://uk.trustpilot.com/review/www....
# 2020  {'url': 'https://uk.trustpilot.com/review/www....
#
# [2021 rows x 7 columns]
