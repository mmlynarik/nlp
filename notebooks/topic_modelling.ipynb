# %% [markdown]
# # Topic modelling on train travel comments dataset

# %% [markdown]
# ## 1. Set up environment and load dataset

# %%
import json
import warnings
from typing import List, Any
from functools import wraps
from time import time

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cbook
import gensim
import tqdm
import nltk
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
from gensim.utils import simple_preprocess, ClippedCorpus
from gensim.parsing.preprocessing import STOPWORDS
from gensim.models import Phrases, CoherenceModel
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')
plt.style.use("ggplot") 
warnings.filterwarnings(action="ignore", category=matplotlib.cbook.mplDeprecation)
warnings.simplefilter(action='ignore', category=FutureWarning)

# %reload_ext autoreload
# %autoreload 2
# Out:
# [nltk_data] Downloading package wordnet to /home/miro/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
reviews_file = open("../data/train_reviews.json")
reviews_dict = json.load(reviews_file)

# %% [markdown]
# ## 2. Basic dataset preprocessing

# %% [markdown]
#  - Convert dictionary object into pandas dataframe, normalize `date` column, create `period` column representing **year-month**, **company** column extracted from url and expand `stars` column.

# %%
reviews = pd.DataFrame(reviews_dict)
reviews.head()
# Out:
#                             date  \
# 0  2015-10-10T14:32:51.000+00:00
# 1  2015-09-22T17:04:56.000+00:00
# 2  2015-03-13T23:37:05.000+00:00
# 3  2015-01-13T12:26:52.000+00:00
# 4  2011-05-28T15:00:36.000+00:00
#
#                                                title  \
# 0  Bad customer service. Staff are very impolite ...
# 1                               Pretty awful service
# 2                                        Awful staff
# 3                                          Very good
# 4                                      Check it out.
#
#                                                 text  \
# 0  Used national rail twice and on both occasions...
# 1  I phoned National rail to find out why several...
# 2  I travel from Brokenhast to southampton centra...
# 3  Saved about £50 on a single trip using Nationa...
# 4  I always use the national rail enquiry site wh...
#
#                                                  url  \
# 0  https://uk.trustpilot.com/review/www.nationalr...
# 1  https://uk.trustpilot.com/review/www.nationalr...
# 2  https://uk.trustpilot.com/review/www.nationalr...
# 3  https://uk.trustpilot.com/review/www.nationalr...
# 4  https://uk.trustpilot.com/review/www.nationalr...
#
#                                            stars
# 0  star-rating star-rating-1 star-rating--medium
# 1  star-rating star-rating-1 star-rating--medium
# 2  star-rating star-rating-1 star-rating--medium
# 3  star-rating star-rating-4 star-rating--medium
# 4  star-rating star-rating-4 star-rating--medium

# %%
reviews["date"] = pd.to_datetime(reviews['date'])
reviews["period"] = reviews.date.dt.strftime('%Y-%m')
reviews["year"] = reviews.date.dt.year
reviews["company"] = reviews.url.str.replace("https://uk.trustpilot.com/review/www.", "", regex=False).str.split(".", expand=True)[0]

expanded_stars = reviews["stars"].str.split(expand=True).rename(columns={0: 'rating_type', 1: 'rating_id', 2: 'rating_level'})
reviews[expanded_stars.columns] = expanded_stars
reviews = reviews.drop(columns=["stars", "url"])

# %% [markdown]
# - Check if all ratings are of the same type and level.

# %%
print(f"""The unique rating types and levels are as follows:
{reviews.rating_type.unique().tolist()}, {reviews.rating_level.unique().tolist()}""")
# Out:
# The unique rating types and levels are as follows:
# ['star-rating'], ['star-rating--medium']

# %% [markdown]
# - Drop irrelevant `rating_type`and `rating_level` columns and convert `rating_id` into numeric column.

# %%
reviews = reviews.drop(columns={'rating_type', 'rating_level'}, errors='ignore')
if reviews.rating_id.dtype != 'int64':
    reviews['rating_id'] = reviews['rating_id'].str.strip("star-rating").astype(int)
reviews = reviews.reindex(columns=["date", "period", "year", "company", "title", "text", "rating_id"])
reviews.head()
# Out:
#                        date   period  year       company  \
# 0 2015-10-10 14:32:51+00:00  2015-10  2015  nationalrail
# 1 2015-09-22 17:04:56+00:00  2015-09  2015  nationalrail
# 2 2015-03-13 23:37:05+00:00  2015-03  2015  nationalrail
# 3 2015-01-13 12:26:52+00:00  2015-01  2015  nationalrail
# 4 2011-05-28 15:00:36+00:00  2011-05  2011  nationalrail
#
#                                                title  \
# 0  Bad customer service. Staff are very impolite ...
# 1                               Pretty awful service
# 2                                        Awful staff
# 3                                          Very good
# 4                                      Check it out.
#
#                                                 text  rating_id
# 0  Used national rail twice and on both occasions...          1
# 1  I phoned National rail to find out why several...          1
# 2  I travel from Brokenhast to southampton centra...          1
# 3  Saved about £50 on a single trip using Nationa...          4
# 4  I always use the national rail enquiry site wh...          4

# %% [markdown]
# ## 3. Exploratory data analysis

# %% [markdown]
# - Since the number of observations in year 2011 is only 2, we will delete that year so that only contiguous period of years 2015-2018 remained.

# %%
print(reviews.year.value_counts().tail(1))
reviews = reviews[reviews.year != 2011].reset_index(drop=True)
# Out:
# 2011    2
# Name: year, dtype: int64

# %% [markdown]
# - **Eliminate 580 duplicated reviews** in order not to train model on redundant information.

# %%
reviews = reviews.drop_duplicates().reset_index(drop=True)
reviews.shape
# Out:
# (1439, 7)

# %% [markdown]
# - Check the ratings distribution over years. We can see the **trend of increased dissatisfaction with the railway service** (on condition that `rating=1` is the worst rating grade). Also, we can see that reviews have been submitted primarily for six companies. **We also see that the overall number of reviews with positive rating (`rating_id` > 3) is rather small (~150). We will therefore exclude them from the development sample to be in line with the assignment (to find out suggestions for service improvements).**

# %%
fig, axs = plt.subplots(1, 3, figsize=(32, 5),  gridspec_kw={'width_ratios': [1, 2, 1]})
sns.countplot(x="year", hue="rating_id", data=reviews, ax=axs[0])
axs[0].set_title("Reviews distribution by year and rating")

sns.countplot(x="company", data=reviews, ax=axs[1])
axs[1].set_title("Reviews distribution by company")
axs[1].tick_params(axis="x", rotation=45);

sns.countplot(x="rating_id", data=reviews, ax=axs[2])
axs[2].set_title("Reviews distribution by rating");

# %% [markdown]
# - After exclusion of positive reviews:

# %%
reviews = reviews[reviews.rating_id < 4].reset_index(drop=True)
print(reviews.shape)

fig, axs = plt.subplots(1, 3, figsize=(32, 5),  gridspec_kw={'width_ratios': [1, 2, 1]})
sns.countplot(x="year", hue="rating_id", data=reviews, ax=axs[0])
axs[0].set_title("Reviews distribution by year and rating")

sns.countplot(x="company", data=reviews, ax=axs[1])
axs[1].set_title("Reviews distribution by company")
axs[1].tick_params(axis="x", rotation=45);

sns.countplot(x="rating_id", data=reviews, ax=axs[2])
axs[2].set_title("Reviews distribution by rating");
# Out:
# (1275, 7)

# %% [markdown]
# - Distribution of reviews by month shows that the **number of reviews increased in first two years, then culminated at around 500 reviews per year.**

# %%
fig, axs = plt.subplots(1, 2, figsize=(32, 6), gridspec_kw={'width_ratios': [3, 1]})
sns.countplot(x="period", data=reviews, order=reviews.period.value_counts().index.sort_values(), ax=axs[0])
axs[0].set_title("Reviews count by month")
axs[0].tick_params(axis="x", rotation=45)
sns.countplot(x="year", data=reviews, ax=axs[1])
axs[1].set_title("Reviews count by year");

# %% [markdown]
# - Check the distribution of review title lengths to find out whether, by chance, reviewers did not enter the review into title. At the same time, check the distribution of review text lengths. The means and standard deviations are displayed in figure titles. **Figures show that the reviews are actually restricted to text field and the title can be effectively ignored.**

# %%
titles_list = [title for title in reviews.title.str.split()]
titles_lengths = pd.DataFrame(data={"length": [len(title) for title in titles_list]})

texts_list = [text for text in reviews.text.str.split()]
texts_lengths = pd.DataFrame(data={"length": [len(text) for text in texts_list]}).round(-1)

fig, axs = plt.subplots(1, 2, figsize=(32, 6), gridspec_kw={'width_ratios': [1, 3]})
sns.countplot(x="length", data=titles_lengths, ax=axs[0])
axs[0].set_title(f"Review title length distribution, mean: {titles_lengths.mean().values[0]:,.2f}, std: {titles_lengths.std().values[0]:,.2f}")
sns.countplot(x="length", data=texts_lengths, ax=axs[1])
axs[1].set_title(f"Review text length distribution, mean: {texts_lengths.mean().values[0]:,.2f}, std: {texts_lengths.std().values[0]:,.2f}");

# %% [markdown]
# ## 4. Reviews text preprocessing

# %% [markdown]
# - Define helper functions.

# %%
def tokenize(docs: pd.Series, min_len: int = 2, max_len: int = 30) -> List[List[str]]:
    return [simple_preprocess(doc, deacc=True, min_len=min_len, max_len=max_len) for doc in docs]
        
def lemmatize(tokenized_docs: List[List[str]], lemmatizer: Any) -> List[List[str]]:
    res = [[lemmatizer.lemmatize(lemmatizer.lemmatize(token, pos='v'), pos='n')
            for token in doc] for doc in tokenized_docs]
    return res

def add_trigram_phrases(lemmatized_docs: List[List[str]], min_count: int, threshold: int) -> List[List[str]]:
    bigram_model = Phrases(lemmatized_docs, min_count=min_count, threshold=threshold)
    trigram_model = Phrases(bigram_model[lemmatized_docs], min_count=min_count, threshold=threshold)
    res = list(trigram_model[bigram_model[lemmatized_docs]])
    return res
     
def filter_stopwords(phrased_docs: List[List[str]]) -> List[List[str]]:
    return [[token for token in doc if token not in STOPWORDS] for doc in phrased_docs]   
    
def filter_short_tokens(filtered_stopwords_docs: List[List[str]], min_len: int = 3) -> List[List[str]]:
    return [[token for token in doc if len(token) >= min_len] for doc in filtered_stopwords_docs]

# %% [markdown]
# - Apply consecutive tokenization, deaccentation, **WordNet** lemmatization, trigrams addition, stopwords filtering and short token filtering to each review text to produce processed documents, i.e. list of lists of tokens. We decided not to use stemmer, because we wanted to keep actual words in the dictionary instead of trimmed ones in order to easily interpret the predicted topics.

# %%
lemmatizer = WordNetLemmatizer()
docs = reviews.text

tokenized_docs = tokenize(docs, min_len=2, max_len=20)
lemmatized_docs = lemmatize(tokenized_docs, lemmatizer)
phrased_docs = add_trigram_phrases(lemmatized_docs, min_count=2, threshold=10)
filtered_stopwords_docs = filter_stopwords(phrased_docs)
processed_docs = filter_short_tokens(filtered_stopwords_docs, min_len=3)

# %% [markdown]
# ## 5. Gensim LDA model

# %% [markdown]
# - Define helper function.

# %%
def calc_coherence_metric(corpus, dictionary, topics, processed_docs, alpha, eta):
    lda_model = gensim.models.LdaModel(corpus=corpus,
                                       id2word=dictionary,
                                       num_topics=topics,
                                       passes=10,
                                       alpha=alpha,
                                       eta=eta,
                                       minimum_probability=0.1,
                                       random_state=10)
    
    coherence_model = CoherenceModel(model=lda_model,
                                     texts=processed_docs,
                                     corpus=corpus,
                                     coherence='c_v')
    
    return coherence_model.get_coherence()

# %% [markdown]
# - Plug tokenized documents into **gensim Dictionary** object and apply **filter_extremes function** filtering tokens that occur in less than 5 or in above 10% of documents. Then calculate **bag-of-words corpus** from the tokenized documents using the dictionary.

# %%
dictionary = gensim.corpora.Dictionary(processed_docs)
dictionary.filter_extremes(no_below=5, no_above=0.1, keep_n=100_000)

bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
corpus_size, dictionary_size = len(bow_corpus), len(dictionary)

print(f"Number of documents in the bow corpus is: {corpus_size}")
print(f"Number of words/tokens in the dictionary is: {dictionary_size}")
# Out:
# Number of documents in the bow corpus is: 1275
# Number of words/tokens in the dictionary is: 1403

# %% [markdown]
# - Check how the bag of words looks for a sample document selected from the corpus.

# %%
doc = 1000
bow_doc_x = bow_corpus[doc]

for i in range(len(bow_doc_x)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_x[i][0], dictionary[bow_doc_x[i][0]], bow_doc_x[i][1]))
# Out:
# Word 15 ("brighton") appears 1 time.
# Word 78 ("announce") appears 1 time.
# Word 107 ("bus") appears 1 time.
# Word 132 ("price") appears 1 time.
# Word 193 ("route") appears 1 time.
# Word 241 ("year") appears 1 time.
# Word 534 ("able_to") appears 1 time.
# Word 587 ("of_course") appears 1 time.
# Word 701 ("in_advance") appears 1 time.
# Word 771 ("cost") appears 1 time.
# Word 897 ("involve") appears 1 time.
# Word 990 ("a_long") appears 1 time.
# Word 1076 ("direct") appears 1 time.
# Word 1077 ("between_london") appears 1 time.
# Word 1120 ("highly") appears 1 time.
# Word 1183 ("so_many_time") appears 1 time.
# Word 1198 ("southern") appears 1 time.
# Word 1230 ("ongoing") appears 1 time.
# Word 1252 ("way_home") appears 1 time.

# %% [markdown]
# - Train the LDA model using bow_corpus and dictionary objects, using grid search method on the whole corpus. **Even though we've found the optimal alpha, eta and number of topics based on the optimisation of coherence metric, we decided to use a manually found combination of hyperparameters because our version proved to identify much more discriminated topics than that extracted from grid search.**

# %%
# min_topics, max_topics, step = 8, 13, 2

# topics_range = range(min_topics, max_topics, step)
# alphas = [0.1, 0.3, 0.5, 0.7, 1, 1.5] 
# etas = [0.1, 0.3, 0.5, 0.7, 1, 1.5]
# model_results = {'topics': [], 'alphas': [], 'etas': [], 'coherences': []}

# for topics in topics_range:
#     for alpha in alphas:
#         for eta in etas:
#             print(f"Params: topics: {topics}, alpha: {alpha}, eta: {eta}")
#             coherence = calc_coherence_metric(corpus=bow_corpus, 
#                                               dictionary=dictionary,
#                                               topics=topics, 
#                                               processed_docs=processed_docs,
#                                               alpha=alpha,
#                                               eta=eta)

#             model_results['topics'].append(topics)
#             model_results['alphas'].append(alpha)
#             model_results['etas'].append(eta)
#             model_results['coherences'].append(coherence)
                
# results = pd.DataFrame(model_results)

# %%
# results.sort_values(["coherences"], ascending=False).head(10)

# %% [markdown]
# - Our "manual" combination of hyperparameters with lower coherence score:

# %%
num_topics = 10

lda_model = gensim.models.LdaModel(corpus=bow_corpus, 
                                   num_topics=num_topics, 
                                   id2word=dictionary,                                    
                                   passes=10,
                                   alpha=0.7,
                                   eta=1,
                                   minimum_probability=0.1,
                                   random_state=10)

coherence_model = CoherenceModel(model=lda_model, texts=processed_docs, corpus=bow_corpus, coherence='c_v')
coherence = coherence_model.get_coherence()
print('Coherence Score: ', coherence)
# Out:
# Coherence Score:  0.2901808862749015

# %%
from gensim.models.wrappers.ldamallet import malletmodel2ldamodel
from gensim.models.wrappers import LdaMallet

num_topics = 6
mallet_path = "../mallet/bin/mallet"
lda_model = gensim.models.wrappers.LdaMallet(mallet_path,
                                             corpus=bow_corpus,
                                             alpha=0.01,
                                             workers=1,
                                             topic_threshold=0.01,
                                             random_seed=10,
                                             num_topics=num_topics,
                                             id2word=dictionary);

lda_model = malletmodel2ldamodel(lda_model)

coherence_model = CoherenceModel(model=lda_model, texts=processed_docs, corpus=bow_corpus, coherence='c_v')
coherence = coherence_model.get_coherence()
print('Coherence Score: ', coherence)
# Out:
# Mallet LDA: 6 topics, 3 topic bits, 111 topic mask
# Data loaded.
# max tokens: 180
# total tokens: 20288
# <10> LL/token: -8.08559
# <20> LL/token: -7.97388
# <30> LL/token: -7.90648
# <40> LL/token: -7.86225
#
# 0	0.00167	pay eurostar virgin change do_not experience people station board due_to arrive hour leave advise st_class queue trip first_class wait at_least
# 1	0.00167	price customer gwr run first_class southern good complaint fare charge website experience worst carriage appal eurostar provide business company joke
# 2	0.00167	virgin customer_service wait website change hour minute refund if_you buy virgin_train cost virgin_staff passenger email pay_for due_to month couldn price
# 3	0.00167	pay station virgin_train virgin first_class late offer company buy leave people food minute tell_me purchase guard eurostar line week customer_service
# 4	0.00167	refund customer_service phone email send eurostar reply website change do_not company customer money request receive complaint month online pay return
# 5	0.00167	people customer company minute carriage run late stand due_to overcrowd passenger coach money virgin_train stop station toilet virgin review hour
#
# <50> LL/token: -7.84253
# <60> LL/token: -7.82249
# <70> LL/token: -7.8042
# <80> LL/token: -7.7918
# <90> LL/token: -7.77095
#
# 0	0.00167	pay eurostar people change board due_to do_not station experience gwr queue virgin trip bus arrive advise late poor if_you at_least
# 1	0.00167	price customer run first_class southern fare carriage charge company complaint gwr experience good business southern_rail website overcrowd joke worst money
# 2	0.00167	virgin hour customer_service change wait company buy pay_for minute refund website station virgin_staff virgin_train if_you newcastle price awful run eurostar
# 3	0.00167	virgin station pay food virgin_train first_class offer minute leave purchase late people print customer_service arrive platform cost passenger customer explain
# 4	0.00167	refund customer_service email phone reply send website change eurostar company complaint compensation do_not request speak money receive leave online month
# 5	0.00167	people stand virgin_train late run passenger customer minute toilet due_to stop coach carriage company overcrowd dirty avoid money terrible station
#
# <100> LL/token: -7.76517
# <110> LL/token: -7.74581
# <120> LL/token: -7.73815
# <130> LL/token: -7.71844
# <140> LL/token: -7.71743
#
# 0	0.00167	eurostar station pay change people board gwr paris experience queue buy virgin arrive check trip st_class poor advise hour rude
# 1	0.00167	price customer run company southern experience first_class good southern_rail fare worst business carriage charge gwr overcrowd commute virgin_train bad provide
# 2	0.00167	virgin customer_service change hour wait website company minute buy pay_for refund virgin_staff if_you price cost purchase virgin_train offer trip southern
# 3	0.00167	station virgin food leave pay first_class virgin_train customer_service customer passenger minute people offer explain platform eurostar print late breakfast buy
# 4	0.00167	refund email phone reply customer_service complaint send website compensation change money do_not eurostar receive company request week customer tell_me contact
# 5	0.00167	people carriage due_to passenger late stand toilet minute virgin_train do_not customer run coach pay overcrowd station line review company terrible
#
# <150> LL/token: -7.71085
# <160> LL/token: -7.70038
# <170> LL/token: -7.69422
# <180> LL/token: -7.68958
# <190> LL/token: -7.68864
#
# 0	0.00167	eurostar pay change people do_not buy experience queue gwr board hour station paris food arrive advise expect good wait poor
# 1	0.00167	price run company southern customer pay southern_rail first_class fare station experience good bad charge business worst commute sell manchester people
# 2	0.00167	virgin customer_service change minute hour wait company website buy virgin_train price virgin_staff cost refund pay_for station run trip machine purchase
# 3	0.00167	first_class station virgin offer leave eurostar people passenger customer_service virgin_train platform food pay print customer tell_me purchase breakfast explain out_of
# 4	0.00167	refund customer_service email phone reply complaint send website change receive eurostar compensation do_not company money customer week speak request due_to
# 5	0.00167	carriage people due_to passenger customer late stand virgin_train toilet run virgin minute gwr pay company overcrowd coach terrible worst wait_for
#
# <200> LL/token: -7.67918
# <210> LL/token: -7.67299
# <220> LL/token: -7.66883
# <230> LL/token: -7.67155
# <240> LL/token: -7.6721
#
# 0	0.00167	eurostar pay people change paris board queue gwr experience hour do_not leave food wait arrive st_class feel bus buy expect
# 1	0.00167	price company run customer southern first_class business experience good worst charge southern_rail joke pay fare offer bad overcrowd commute line
# 2	0.00167	virgin customer_service change buy minute hour company wait website virgin_train price if_you virgin_staff refund leave pay_for station run return_ticket cost
# 3	0.00167	virgin station first_class pay customer_service virgin_train offer food people print customer eurostar passenger minute breakfast purchase tell_me return leave explain
# 4	0.00167	refund customer_service email reply phone send complaint website change compensation receive do_not customer eurostar request contact week tell_me virgin_train speak
# 5	0.00167	passenger carriage people due_to station toilet late run stand virgin_train minute company stop virgin overcrowd gwr coach platform dirty money
#
# <250> LL/token: -7.66036
# <260> LL/token: -7.659
# <270> LL/token: -7.66007
# <280> LL/token: -7.65666
# <290> LL/token: -7.64832
#
# 0	0.00167	eurostar people pay board experience buy queue wait change week bus arrive st_class paris hour do_not station min good poor
# 1	0.00167	price run customer southern company experience eurostar business worst pay southern_rail late charge change fare first_class good commute money leave
# 2	0.00167	virgin customer_service change hour minute buy website wait company price cost virgin_train refund station eurostar virgin_staff if_you run trip policy
# 3	0.00167	first_class virgin station food pay leave customer offer virgin_train company passenger customer_service breakfast people explain tell_me edinburgh sandwich situation purchase
# 4	0.00167	refund email customer_service reply phone send complaint website week tell_me receive customer compensation change do_not eurostar contact request virgin money
# 5	0.00167	carriage passenger toilet people late due_to stand virgin_train company station minute run gwr virgin overcrowd coach dirty do_not guard platform
#
# <300> LL/token: -7.65456
# <310> LL/token: -7.63898
# <320> LL/token: -7.64261
# <330> LL/token: -7.64209
# <340> LL/token: -7.6369
#
# 0	0.00167	eurostar people pay change wait paris queue board experience do_not station buy bus leave arrive week line check st_class good
# 1	0.00167	price customer southern run company pay worst start southern_rail business experience first_class fare people joke bad gwr commute good poor
# 2	0.00167	virgin customer_service hour change website minute refund price buy wait company cost virgin_staff phone number virgin_train pay_for policy newcastle customer
# 3	0.00167	first_class virgin food pay station virgin_train customer offer explain company buy edinburgh purchase customer_service breakfast sandwich eurostar st_class minute talk
# 4	0.00167	refund customer_service email reply phone send complaint website do_not compensation change customer receive tell_me virgin request week eurostar contact answer
# 5	0.00167	carriage passenger run toilet due_to people virgin_train late stand company minute station overcrowd gwr leave dirty coach terrible pay guard
#
# <350> LL/token: -7.63801
# <360> LL/token: -7.63079
# <370> LL/token: -7.63218
# <380> LL/token: -7.63113
# <390> LL/token: -7.62725
#
# 0	0.00167	eurostar pay people do_not queue experience paris wait arrive change board buy week station trip min hour bus due_to late
# 1	0.00167	price company southern experience run customer southern_rail worst bad business fare good first_class commute joke people absolutely start gwr shock
# 2	0.00167	virgin customer_service change hour buy refund price company wait minute website pay_for newcastle virgin_train station virgin_staff phone cost eurostar return_ticket
# 3	0.00167	first_class food virgin customer virgin_train leave pay explain station customer_service offer eurostar breakfast st_class sandwich edinburgh passenger tell_me ask_for return
# 4	0.00167	refund email customer_service reply phone complaint send website change receive compensation do_not tell_me week customer virgin virgin_train request money answer
# 5	0.00167	carriage people passenger run late toilet company stand station gwr minute leave virgin_train due_to money customer overcrowd pay virgin stop
#
# <400> LL/token: -7.62312
# <410> LL/token: -7.6246
# <420> LL/token: -7.62173
# <430> LL/token: -7.61612
# <440> LL/token: -7.62278
#
# 0	0.00167	eurostar pay people paris station leave board queue change wait bus arrive experience late do_not week at_least min poor buy
# 1	0.00167	price company southern customer run experience southern_rail first_class business bad people fare start eurostar commute joke worst poor gwr good
# 2	0.00167	virgin customer_service hour change virgin_train company price refund wait minute buy website pay_for station virgin_staff eurostar leave return_ticket newcastle money
# 3	0.00167	first_class virgin food virgin_train offer pay passenger explain st_class customer buy tell_me rude breakfast sandwich customer_service station talk edinburgh coffee
# 4	0.00167	refund email phone customer_service reply complaint send website receive change customer do_not compensation tell_me virgin request answer pay contact week
# 5	0.00167	carriage people passenger run late toilet stand company due_to virgin_train gwr minute overcrowd stop money do_not station worst pay platform
#
# <450> LL/token: -7.615
# <460> LL/token: -7.61721
# <470> LL/token: -7.61757
# <480> LL/token: -7.60411
# <490> LL/token: -7.60654
#
# 0	0.00167	eurostar pay paris people change leave arrive queue board due_to station do_not wait bus trip charge late week min at_least
# 1	0.00167	run southern price customer experience company pay fare southern_rail first_class business start bad charge joke worst money change good website
# 2	0.00167	virgin customer_service price company buy hour refund change wait website minute virgin_staff virgin_train money eurostar cost pay_for online return_ticket lose
# 3	0.00167	first_class food virgin offer virgin_train st_class customer_service people passenger rude explain edinburgh sandwich buy platform customer breakfast drink coffee ask_for
# 4	0.00167	refund email customer_service phone reply complaint send website change do_not receive compensation tell_me virgin customer answer contact request week pay
# 5	0.00167	carriage people passenger late company due_to toilet run stand station gwr virgin_train stop minute overcrowd worst virgin customer leave board
#
# <500> LL/token: -7.6081
# <510> LL/token: -7.59994
# <520> LL/token: -7.60168
# <530> LL/token: -7.59582
# <540> LL/token: -7.60221
#
# 0	0.00167	eurostar people station pay paris change queue board experience do_not wait arrive bus late due_to charge passenger week leave we_could
# 1	0.00167	company southern customer price run pay southern_rail experience start station business commute change good late fare bad thing line money
# 2	0.00167	virgin customer_service company buy website price hour virgin_train pay_for eurostar refund minute change wait trip online lose return_ticket leave customer
# 3	0.00167	first_class food virgin st_class virgin_train offer sandwich pay buy tell_me edinburgh return rude customer_service explain breakfast coffee connection ask_for customer
# 4	0.00167	refund customer_service email phone reply complaint send website change receive answer do_not customer compensation virgin tell_me week contact request speak
# 5	0.00167	carriage people passenger due_to toilet run gwr late stand company leave virgin virgin_train stop overcrowd worst hour money platform car
#
# <550> LL/token: -7.59462
# <560> LL/token: -7.59533
# <570> LL/token: -7.59108
# <580> LL/token: -7.5863
# <590> LL/token: -7.58705
#
# 0	0.00167	eurostar people pay station paris arrive do_not queue board leave experience late poor charge we_could expect buy change hour bus
# 1	0.00167	customer southern experience company price business southern_rail run good start pay commute fare eurostar bad manchester charge appal great drive
# 2	0.00167	virgin change price customer_service buy company website hour virgin_train station leave purchase refund online eurostar virgin_staff pay_for wait date check
# 3	0.00167	first_class virgin food offer st_class pay virgin_train edinburgh sandwich serve customer rude breakfast drink customer_service tell_me coffee ask_for explain connection
# 4	0.00167	refund customer_service email phone reply complaint send website do_not change receive compensation tell_me answer week money contact speak request if_you
# 5	0.00167	carriage passenger people run company toilet due_to late stand gwr virgin_train minute station overcrowd stop worst virgin leave platform money
#
# <600> LL/token: -7.58119
# <610> LL/token: -7.58212
# <620> LL/token: -7.57505
# <630> LL/token: -7.57691
# <640> LL/token: -7.56559
#
# 0	0.00167	eurostar pay people paris station queue do_not leave charge arrive board poor experience bus change hour minute expect complete at_least
# 1	0.00167	customer company run southern experience price pay bad business southern_rail commute start fare customer_service awful virgin_train thing hold great good
# 2	0.00167	virgin price customer_service buy website change company eurostar virgin_staff purchase hour newcastle virgin_train pay_for leave return online southern refund minute
# 3	0.00167	first_class food virgin st_class offer customer pay edinburgh sandwich serve breakfast drink customer_service tell_me ask_for coffee passenger rude pay_for trip
# 4	0.00167	refund email customer_service phone reply complaint send customer change website compensation receive do_not answer week virgin_train if_you speak money tell_me
# 5	0.00167	carriage people passenger due_to run late toilet company gwr stand virgin_train station stop leave worst minute money overcrowd platform coach
#
# <650> LL/token: -7.56916
# <660> LL/token: -7.57067
# <670> LL/token: -7.56452
# <680> LL/token: -7.56623
# <690> LL/token: -7.5732
#
# 0	0.00167	eurostar people paris pay leave queue station board do_not charge arrive bus experience poor we_could hour wait minute awful early
# 1	0.00167	customer southern run company experience price pay southern_rail business bad customer_service commute virgin_train good start late great joke poor thing
# 2	0.00167	virgin customer_service price change buy website company virgin_train leave station eurostar virgin_staff purchase trip refund online minute return_ticket edinburgh hour
# 3	0.00167	first_class food virgin st_class virgin_train customer customer_service pay drink sandwich offer buy edinburgh breakfast rude tell_me serve completely explain coffee
# 4	0.00167	refund email phone complaint reply customer_service send change compensation receive do_not money website answer week virgin customer tell_me speak claim
# 5	0.00167	carriage passenger people due_to run toilet late station company gwr stand overcrowd stop hour worst virgin minute platform virgin_train leave
#
# <700> LL/token: -7.56159
# <710> LL/token: -7.56486
# <720> LL/token: -7.57187
# <730> LL/token: -7.56186
# <740> LL/token: -7.56543
#
# 0	0.00167	eurostar people paris pay station do_not queue board arrive bus poor charge change we_could experience fare if_you leave check_in provide
# 1	0.00167	customer southern price company experience run pay bad southern_rail good commute virgin_train business start drive at_all joke money worst long
# 2	0.00167	virgin website customer_service price company buy change leave hour station eurostar virgin_train virgin_staff trip purchase minute refund newcastle return return_ticket
# 3	0.00167	first_class food virgin offer st_class customer edinburgh sandwich pay connection breakfast serve customer_service buy drink coffee virgin_train passenger tell_me expect
# 4	0.00167	refund email customer_service reply phone complaint send receive change week answer compensation customer website do_not online virgin_train due_to contact tell_me
# 5	0.00167	carriage passenger run people due_to late gwr company toilet stand station virgin_train stop hour leave worst overcrowd minute platform money
#
# <750> LL/token: -7.55618
# <760> LL/token: -7.56818
# <770> LL/token: -7.56364
# <780> LL/token: -7.55235
# <790> LL/token: -7.55906
#
# 0	0.00167	eurostar people paris pay queue do_not station arrive change leave board poor charge bus experience we_could wait check_in trip minute
# 1	0.00167	customer company southern price run experience pay virgin_train bad commute good southern_rail awful eurostar fare minute business start poor passenger
# 2	0.00167	virgin price website customer_service buy company change leave eurostar virgin_train purchase virgin_staff return online cost trip hour pay_for customer station
# 3	0.00167	first_class food virgin st_class pay offer virgin_train sandwich drink rude tell_me edinburgh breakfast serve on_board buy upgrade refreshment first_class_ticket ask_for
# 4	0.00167	refund customer_service email reply phone complaint send receive change website customer compensation do_not money answer week pay station due_to contact
# 5	0.00167	passenger carriage people run late company gwr due_to toilet stand station virgin leave platform hour worst virgin_train stop money overcrowd
#
# <800> LL/token: -7.55447
# <810> LL/token: -7.56053
# <820> LL/token: -7.56536
# <830> LL/token: -7.5556
# <840> LL/token: -7.55232
#
# 0	0.00167	eurostar people paris queue do_not pay leave station board charge change hour poor arrive trip awful bus check_in if_you due_to
# 1	0.00167	customer run company experience southern southern_rail bad price start good joke station commute line fare pay virgin_train thing late people
# 2	0.00167	virgin change price company website customer_service eurostar buy virgin_train pay_for leave purchase station virgin_staff minute newcastle refund online tell_me even_though
# 3	0.00167	first_class food virgin offer st_class sandwich rude pay edinburgh breakfast virgin_train drink coffee serve buy tell_me first_class_ticket euston upgrade refreshment
# 4	0.00167	refund email reply customer_service phone complaint send compensation money customer receive website do_not change week answer contact if_you pay no_one
# 5	0.00167	passenger carriage late run due_to people station company toilet stand gwr minute virgin_train hour worst leave virgin stop overcrowd platform
#
# <850> LL/token: -7.55709
# <860> LL/token: -7.54791
# <870> LL/token: -7.55087
# <880> LL/token: -7.54815
# <890> LL/token: -7.5415
#
# 0	0.00167	eurostar people paris pay queue leave arrive do_not station experience bus board poor charge awful check_in trip complete rude able_to
# 1	0.00167	customer company southern experience run price pay good southern_rail bad commute first_class year buy virgin_train joke fare station late poor
# 2	0.00167	virgin price company customer_service change buy station eurostar hour pay website virgin_train online minute leave pay_for return purchase tell_me virgin_staff
# 3	0.00167	first_class food virgin st_class offer edinburgh sandwich drink breakfast virgin_train serve buy platform coffee first_class_ticket upgrade refreshment we_could tell_me on_board
# 4	0.00167	refund customer_service email phone reply complaint send receive change website customer compensation answer do_not money speak contact tell_me virgin_train minute
# 5	0.00167	passenger carriage people run due_to late station toilet stand company gwr virgin minute overcrowd stop virgin_train worst hour good couldn
#
# <900> LL/token: -7.5477
# <910> LL/token: -7.54473
# <920> LL/token: -7.54291
# <930> LL/token: -7.53001
# <940> LL/token: -7.5473
#
# 0	0.00167	eurostar people paris pay arrive queue charge leave station board do_not experience if_you due_to poor expect bus awful trip check_in
# 1	0.00167	southern customer company experience southern_rail minute late run price pay bad good line fare station commute virgin_train first_class buy completely
# 2	0.00167	virgin change price website customer_service company buy station leave purchase eurostar return hour pay virgin_train pay_for customer virgin_staff return_ticket trip
# 3	0.00167	first_class food virgin st_class offer sandwich buy drink pay edinburgh breakfast serve rude upgrade make_me ask_for customer explain tell_me refreshment
# 4	0.00167	refund customer_service email phone reply complaint send customer receive answer compensation website week company money do_not contact virgin_train speak online
# 5	0.00167	passenger run carriage people station late toilet due_to stand virgin_train company minute gwr leave platform virgin stop hour worst do_not
#
# <950> LL/token: -7.53598
# <960> LL/token: -7.54176
# <970> LL/token: -7.52819
# <980> LL/token: -7.53276
# <990> LL/token: -7.52943
#
# 0	0.00167	eurostar people paris queue do_not leave change board charge pay arrive experience trip station check_in awful poor french departure at_least
# 1	0.00167	customer southern company run pay experience southern_rail price bad good line joke worst commute virgin_train late fare minute virgin if_you
# 2	0.00167	virgin price customer_service buy change station company purchase pay website eurostar online trip return hour leave problem virgin_train pay_for machine
# 3	0.00167	first_class food virgin st_class virgin_train sandwich offer edinburgh breakfast drink first_class_ticket serve coffee customer_service pay buy upgrade refreshment make_me rude
# 4	0.00167	refund email customer_service reply phone send complaint website tell_me answer change receive do_not compensation week customer speak contact virgin_train no_one
# 5	0.00167	people passenger carriage station due_to run late company toilet stand minute leave gwr virgin_train hour stop overcrowd pay platform worst
#
# <1000> LL/token: -7.52781
#
# Total time: 2 seconds
# Coherence Score:  0.3353312809732636

# %% [markdown]
# ## 6. Topics analysis

# %% [markdown]
# - Define helper functions.

# %%
def topics_in_documents_as_df(topics_in_documents_list, documents_df, num_topics, period_col="year"):
    res = pd.DataFrame(columns=range(num_topics))
    for i, document in enumerate(topics_in_documents_list):
        for topic_weight in document:
            res.loc[i, topic_weight[0]] = topic_weight[1]
        
    res = res.fillna(0)
    res["period"] = documents_df[period_col] 
    return res

def get_representative_docs_for_topic(topics_in_documents, documents_series, topic, n=10):
    indices = topics_in_documents.sort_values(by=topic, ascending=False)[topic].head(n).index 
    print(topics_in_documents.sort_values(by=topic, ascending=False)[topic].head(n))
    for i in range(n):
        print(documents_series[indices].tolist()[i], '\n')

# %% [markdown]
# - Display the identified topics and their most relevant words/tokens.

# %%
for i, topic in lda_model.show_topics(formatted=True, num_topics=num_topics, num_words=10):
    print(str(i) + ": "+ topic, '\n')
# Out:
# 0: 0.041*"eurostar" + 0.016*"paris" + 0.016*"people" + 0.014*"do_not" + 0.014*"leave" + 0.013*"queue" + 0.013*"arrive" + 0.011*"pay" + 0.011*"board" + 0.010*"experience"
#
# 1: 0.016*"southern" + 0.015*"customer" + 0.014*"company" + 0.013*"run" + 0.013*"pay" + 0.011*"southern_rail" + 0.010*"price" + 0.010*"experience" + 0.008*"bad" + 0.008*"virgin_train"
#
# 2: 0.021*"virgin" + 0.016*"change" + 0.016*"customer_service" + 0.016*"price" + 0.014*"station" + 0.014*"buy" + 0.013*"website" + 0.011*"purchase" + 0.011*"eurostar" + 0.011*"company"
#
# 3: 0.032*"first_class" + 0.030*"food" + 0.023*"virgin" + 0.017*"st_class" + 0.014*"pay" + 0.013*"offer" + 0.012*"edinburgh" + 0.012*"drink" + 0.012*"sandwich" + 0.011*"first_class_ticket"
#
# 4: 0.026*"refund" + 0.019*"email" + 0.018*"customer_service" + 0.016*"reply" + 0.016*"phone" + 0.015*"send" + 0.015*"complaint" + 0.010*"customer" + 0.010*"website" + 0.009*"tell_me"
#
# 5: 0.010*"passenger" + 0.010*"carriage" + 0.009*"people" + 0.009*"station" + 0.008*"due_to" + 0.008*"run" + 0.008*"late" + 0.007*"company" + 0.007*"toilet" + 0.007*"stand"

# %% [markdown]
# - Visualise identified topics using `pyLDAvis` package. **We can see that topics are well separated using PCA (principal component analysis).**

# %%
data = gensimvis.prepare(lda_model, bow_corpus, dictionary)
pyLDAvis.display(data)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el2888051399973888694089261220691"></div>
# <script type="text/javascript">
#
# var ldavis_el2888051399973888694089261220691_data = {"mdsDat": {"x": [0.10311294028849699, -0.02920345106212692, 0.13984154514561126, -0.023042123094426183, 0.15892050846673209, -0.3496294197442871], "y": [0.040701899947015535, 0.20820529772859564, 0.0005847524098647264, 0.13482448896626703, -0.2545670266922635, -0.12974941235947907], "topics": [1, 2, 3, 4, 5, 6], "cluster": [1, 1, 1, 1, 1, 1], "Freq": [38.11646443978089, 19.05695529934788, 12.956433814481489, 12.617671807617084, 9.265872513887604, 7.98660212488505]}, "tinfo": {"Term": ["eurostar", "first_class", "refund", "virgin", "food", "email", "reply", "price", "phone", "do_not", "send", "complaint", "customer_service", "st_class", "pay", "people", "run", "southern", "carriage", "paris", "leave", "station", "website", "board", "buy", "offer", "company", "arrive", "queue", "passenger", "positive", "design", "embarrass", "disappoint", "every_single", "school", "stand_in", "other_passenger", "area", "car", "ruin", "appal_service", "cramp", "cattle", "corridor", "degree", "member", "write_this", "angry", "hundred_of", "you_can_get", "member_of", "shoulder", "stupid", "british", "british_rail", "sleep", "temperature", "worst_company", "don_know", "carriage", "pack", "luggage", "glasgow", "on_top_of", "cross_country", "sit_in", "fast", "window", "or_cancel", "cover", "over_crowd", "room", "quiet", "rush", "laugh", "approach", "idea", "aisle", "young", "toilet", "floor", "stand", "announcement", "passenger", "arrive_at", "overcrowd", "catch", "snow", "space", "stop", "sit_on", "extremely", "coach", "reserve_seat", "guard", "platform", "stick", "head", "due_to", "late", "run", "break", "people", "station", "gwr", "worst", "driver", "minute", "company", "start", "board", "good", "couldn", "leave", "virgin_train", "hour", "avoid", "virgin", "do_not", "money", "week", "pay", "pay_for", "customer", "payment", "phone_call", "weather", "raise", "forward", "voucher", "music", "didn_even", "respond", "blame", "summer", "accord", "day_later", "confirmation", "evidence", "steal", "day_before", "resolve", "ring", "department", "send_an_email", "chase", "cheque", "empathy", "incorrect", "call_centre", "out_of_pocket", "call_back", "follow_up", "take_your_money", "call_customer_service", "box", "from_leeds", "telephone", "contact_them", "copy", "an_email", "do_not_want", "email", "reply", "contact", "still_no", "refund", "send", "complaint", "letter", "request", "phone", "answer", "receive", "amend", "tell_me", "speak", "call_them", "deal_with", "customer_service", "compensation", "process", "claim", "person", "form", "website", "accept", "no_one", "customer", "online", "write", "money", "change", "week", "do_not", "minute", "if_you", "month", "virgin_train", "company", "wait", "impact", "afternoon", "imagine", "how_much", "year_old", "fair", "pocket", "not_valid", "quality", "profit", "argument", "between_london", "east", "focus", "sickness", "ongoing", "way_home", "extortionate", "premium", "monthly", "can_remember", "travel_with_eurostar", "by_southern", "gatwick", "from_victoria", "my_son", "delay_or_cancel", "ill", "huge", "daily", "increase", "southern_rail", "southern", "so_many", "operator", "scheme", "delay_repay", "for_year", "their_customer", "customer", "run", "joke", "bad", "shock", "company", "experience", "price", "commute", "pay", "line", "fare", "good", "franchise", "business", "standard", "drive", "year", "virgin_train", "worst", "manchester", "reason", "people", "poor", "first_class", "minute", "late", "awful", "station", "customer_service", "absolutely", "afford", "beware", "new_ticket", "select", "to_buy_another", "download", "prior", "supervisor", "central", "email_confirmation", "entry", "glitch", "order", "circumstance", "receipt", "web_site", "repeatedly", "fight", "go_wrong", "simple", "eurostar_website", "exchange", "new_website", "return_ticket", "main", "confirm", "ticket_online", "ready", "discount", "machine", "come_back", "live", "purchase", "print", "price",  ...

# %% [markdown]
# - Generate documents-topics "TF-IDF-like" matrix (dataframe) useful for further visualisations.

# %%
topics_in_documents_list = [lda_model[bow_corpus[i]] for i, _ in enumerate(bow_corpus)]
topics_in_documents = topics_in_documents_as_df(topics_in_documents_list, documents_df=reviews, num_topics=num_topics, period_col="year")

# %% [markdown]
# - Get top 10 representative documents for selected topic.

# %%
get_representative_docs_for_topic(topics_in_documents, documents_series=reviews.text, topic=5, n=5)
# Out:
# 6      0.999854
# 922    0.999826
# 222    0.999797
# 947    0.999775
# 184    0.999769
# Name: 5, dtype: float64
# National rail is the worst company in Britain. In other developed countries trains run regularly and on time and the company cares when things go wrong. In other developed countries trains are quick and comfortable. Not in Britain. I am currently sat on an already delayed train which is pointing in the direction of Brighton but hasn't moved for the past 15 minutes due to a 'problem'. We have been given no other information nor how long we expect to wait. This is typical of the British railway system and I am in no way surprised; it is second nature for me to factor delays into my journeys now. One positive is that there is no need to worry about missing your train in Britain as they are always at least 5 minutes late, and often closer to 15. I am now stood on the platform of an unknown station after being kicked off the train to Brighton which was deemed unservicable, and I am still not surprised. The price I payed for this third-world service was appalling and the price of trains in general means it is often cheaper to fly to your destination via Spain or Ireland, as well as quicker, easier, more reliable and more comfortable. The entire British rail system is a national disgrace from head office to the 'service' itself. Someone is currently locked in the toilet of the unservicable train and as a result it cannot move to make way for the replacement. The temperature is minus 3. I wish I had slept at Luton Airport until the busses recovered from the horrific two-inch snowfall and resultant traffic chaos.
#
# Last Friday evening due to get the 17-39 train to Eastbourne Station from East Croydon Station but this was cancelled a few minutes before due. Then got the 17-44 train to Ore via Eastbourne but when it arrived late at Haywards Heath we were told that a driver to continue the journey was not available. Waited and waited then told the train would go via Brighton Station instead. Then after more delays train finally left for Brighton where the train stopped for a long time. A new conductor boarded the train but he could not speak English properly and it was almost impossible to understand what he was saying. Train arrived at destination over an hour late. Southern Rail management are entirely responsible for the disastrous unreliable service they provide. It must be hell for the train drivers and guards/conductors employed by Southern Rail to have to bear the brunt of abuse from rail users through no fault of their own. Southern Rail should be fined hundreds of millions of pounds and lose their franchise immediately.
#
# Virgin trains - 3 train cancellations in 1 week, only traveled 4 times in total - what a disaster of train services. The usual template response from them - take a next train..... which might be in 1 hour, but who cares? They don't! As if people do not have schedules and appointments to keep... pathetic excuses, what a circus. Used to be good, key word is 'used', avoid them like plague if you don't want to be stuck in a middle of nowhere with your train suddenly going back....terminated.... and no alternatives offered. After running around the station grabbing everyone in a uniform asking what to do you might get lucky with alternative service offer.... definitely avoid their overpriced and never-on-time-lucky-to-arrive-at-all-services. All 3 cancelled journeys were between Manchester and London, July 2017.
#
# Everyday traveling on southern to London has been a nightmare. The service is always late and everyone seems to have taken it for granted that a journey advertised as 30min will take about 50 in real time. Last evening, just before my stop, they said the train has to go back a station after waiting midtrack for 15min. The driver didn't open the doors at the previous station and we stood 15 more when he announced we'll be going back 2 more spots - that's when I stopped listening. How can this be so mismanaged and unplanned. I pay just as much as any London commuter but the service is so terrible I want to move. Most station staff and passengers are disgruntled and these days I end up seeing/hearing at least one altercation everyday at the station due to train delays. What  are the authorities waiting for  before drastic measures are taken and the condition improved?
#
# I used Virgin trains for the first time this weekend. I didn't reserve a seat because on the train companies I usually use, this is either not possible or not necessary. Not so with Virgin: both trains I took were fully booked, which means that out of 8 or 10 carriages, there is a single one with non-reserved seats. This is obviously not enough for all the people who turn up without a reservation - either because they weren't aware that it is necessary or because they couldn't know in advance which train they would be able to take, or because they missed the one they had reserved seats on. (Virgin charges you for changing a reservation, apprently.) In consequence, I had to sit on the floor outside the toilet for 2 hours, with many fellow-sufferers. The worst thing about this was the smell from the toilet - the chemical disinfectant is so strong that it makes you feel sick when passing the toilet on the outside, let alone sit there for any length of time...

# %% [markdown]
# - Display heatmap plot showing distribution of topics among documents, ordered by documents primary topic. From the colors of the heatmap, we can conclude that we have well separated primary topics in the majority of documents (only some documents are about more than one topic in).

# %%
heatmap_df = topics_in_documents[range(num_topics)]

fig, ax = plt.subplots(1, 1, figsize=(10, 20))
sns.heatmap(heatmap_df.loc[heatmap_df.idxmax(axis=1).sort_values().index], ax=ax);
# Out:
# /home/miro/python/okra/.venv/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /home/miro/python/okra/.venv/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /home/miro/python/okra/.venv/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /home/miro/python/okra/.venv/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /home/miro/python/okra/.venv/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /home/miro/python/okra/.venv/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /home/miro/python/okra/.venv/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /home/miro/python/okra/.venv/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload

# %% [markdown]
# - Display **primary topic distribution** (i.e. the most relevant topic for each document) plot over years. We see generally that most of the topics remained relevant for the whole period of 4 years. Regarding the question of whether the topics changed over years, this question could effectively be answered if we modelled each year separately and compared topics across years - this excercise was quite time demanding so I just outlined the idea/direction I would pursue. However, given the low number of observations and uncertainty in establishing the right labels for each identified topic, it would be relatively imprecise comparison or would require deeper analysis of underlying data.

# %%
primary_topics = pd.DataFrame(data={"topic": topics_in_documents[range(num_topics)].idxmax(axis=1), "period": topics_in_documents.period})
grouped = primary_topics.groupby(["period", "topic"]).agg(count=("topic", "count")).reset_index()
grouped["proportion"] = grouped["count"]/grouped.groupby("period")["count"].transform("sum")

fig, axs = plt.subplots(1, 2, figsize=(32, 5))
axs[0] = sns.countplot(x="period", hue="topic", data=primary_topics, ax=axs[0])
axs[0].set_title("Primary topic distribution over time");

axs[1] = sns.barplot(x="period", y="proportion", hue="topic", data=grouped, ax=axs[1])
axs[1].set_title("Primary topic distribution over time");
plt.legend(loc='upper left');
