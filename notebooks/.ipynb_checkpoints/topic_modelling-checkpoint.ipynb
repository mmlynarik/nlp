# %% [markdown]
# # Topic modelling on train travel comments dataset

# %% [markdown]
# ## 1. Set up environment and load dataset

# %%
import json
import warnings
from typing import List, Any
from functools import wraps
from time import time

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cbook
import gensim
import tqdm
import nltk
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
from gensim.utils import simple_preprocess, ClippedCorpus
from gensim.parsing.preprocessing import STOPWORDS
from gensim.models import Phrases, CoherenceModel
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')
plt.style.use("ggplot") 
warnings.filterwarnings(action="ignore", category=matplotlib.cbook.mplDeprecation)
warnings.simplefilter(action='ignore', category=FutureWarning)

# %reload_ext autoreload
# %autoreload 2
# Out:
# [nltk_data] Downloading package wordnet to /home/miro/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
reviews_file = open("../data/train_reviews.json")
reviews_dict = json.load(reviews_file)

# %% [markdown]
# ## 2. Basic dataset preprocessing

# %% [markdown]
#  - Convert dictionary object into pandas dataframe, normalize `date` column, create `period` column representing **year-month**, **company** column extracted from url and expand `stars` column.

# %%
reviews = pd.DataFrame(reviews_dict)
reviews.head()
# Out:
#                             date  \
# 0  2015-10-10T14:32:51.000+00:00
# 1  2015-09-22T17:04:56.000+00:00
# 2  2015-03-13T23:37:05.000+00:00
# 3  2015-01-13T12:26:52.000+00:00
# 4  2011-05-28T15:00:36.000+00:00
#
#                                                title  \
# 0  Bad customer service. Staff are very impolite ...
# 1                               Pretty awful service
# 2                                        Awful staff
# 3                                          Very good
# 4                                      Check it out.
#
#                                                 text  \
# 0  Used national rail twice and on both occasions...
# 1  I phoned National rail to find out why several...
# 2  I travel from Brokenhast to southampton centra...
# 3  Saved about £50 on a single trip using Nationa...
# 4  I always use the national rail enquiry site wh...
#
#                                                  url  \
# 0  https://uk.trustpilot.com/review/www.nationalr...
# 1  https://uk.trustpilot.com/review/www.nationalr...
# 2  https://uk.trustpilot.com/review/www.nationalr...
# 3  https://uk.trustpilot.com/review/www.nationalr...
# 4  https://uk.trustpilot.com/review/www.nationalr...
#
#                                            stars
# 0  star-rating star-rating-1 star-rating--medium
# 1  star-rating star-rating-1 star-rating--medium
# 2  star-rating star-rating-1 star-rating--medium
# 3  star-rating star-rating-4 star-rating--medium
# 4  star-rating star-rating-4 star-rating--medium

# %%
reviews["date"] = pd.to_datetime(reviews['date'])
reviews["period"] = reviews.date.dt.strftime('%Y-%m')
reviews["year"] = reviews.date.dt.year
reviews["company"] = reviews.url.str.replace("https://uk.trustpilot.com/review/www.", "", regex=False).str.split(".", expand=True)[0]

expanded_stars = reviews["stars"].str.split(expand=True).rename(columns={0: 'rating_type', 1: 'rating_id', 2: 'rating_level'})
reviews[expanded_stars.columns] = expanded_stars
reviews = reviews.drop(columns=["stars", "url"])

# %% [markdown]
# - Check if all ratings are of the same type and level.

# %%
print(f"""The unique rating types and levels are as follows:
{reviews.rating_type.unique().tolist()}, {reviews.rating_level.unique().tolist()}""")
# Out:
# The unique rating types and levels are as follows:
# ['star-rating'], ['star-rating--medium']

# %% [markdown]
# - Drop irrelevant `rating_type`and `rating_level` columns and convert `rating_id` into numeric column.

# %%
reviews = reviews.drop(columns={'rating_type', 'rating_level'}, errors='ignore')
if reviews.rating_id.dtype != 'int64':
    reviews['rating_id'] = reviews['rating_id'].str.strip("star-rating").astype(int)
reviews = reviews.reindex(columns=["date", "period", "year", "company", "title", "text", "rating_id"])
reviews.head()
# Out:
#                        date   period  year       company  \
# 0 2015-10-10 14:32:51+00:00  2015-10  2015  nationalrail
# 1 2015-09-22 17:04:56+00:00  2015-09  2015  nationalrail
# 2 2015-03-13 23:37:05+00:00  2015-03  2015  nationalrail
# 3 2015-01-13 12:26:52+00:00  2015-01  2015  nationalrail
# 4 2011-05-28 15:00:36+00:00  2011-05  2011  nationalrail
#
#                                                title  \
# 0  Bad customer service. Staff are very impolite ...
# 1                               Pretty awful service
# 2                                        Awful staff
# 3                                          Very good
# 4                                      Check it out.
#
#                                                 text  rating_id
# 0  Used national rail twice and on both occasions...          1
# 1  I phoned National rail to find out why several...          1
# 2  I travel from Brokenhast to southampton centra...          1
# 3  Saved about £50 on a single trip using Nationa...          4
# 4  I always use the national rail enquiry site wh...          4

# %% [markdown]
# ## 3. Exploratory data analysis

# %% [markdown]
# - Since the number of observations in year 2011 is only 2, we will delete that year so that only contiguous period of years 2015-2018 remained.

# %%
print(reviews.year.value_counts().tail(1))
reviews = reviews[reviews.year != 2011].reset_index(drop=True)
# Out:
# 2011    2
# Name: year, dtype: int64

# %% [markdown]
# - **Eliminate 580 duplicated reviews** in order not to train model on redundant information.

# %%
reviews = reviews.drop_duplicates().reset_index(drop=True)
reviews.shape
# Out:
# (1439, 7)

# %% [markdown]
# - Check the ratings distribution over years. We can see the **trend of increased dissatisfaction with the railway service** (on condition that `rating=1` is the worst rating grade). Also, we can see that reviews have been submitted primarily for six companies. **We also see that the overall number of reviews with positive rating (`rating_id` > 3) is rather small (~150). We will therefore exclude them from the development sample to be in line with the assignment (to find out suggestions for service improvements).**

# %%
fig, axs = plt.subplots(1, 3, figsize=(32, 5),  gridspec_kw={'width_ratios': [1, 2, 1]})
sns.countplot(x="year", hue="rating_id", data=reviews, ax=axs[0])
axs[0].set_title("Reviews distribution by year and rating")

sns.countplot(x="company", data=reviews, ax=axs[1])
axs[1].set_title("Reviews distribution by company")
axs[1].tick_params(axis="x", rotation=45);

sns.countplot(x="rating_id", data=reviews, ax=axs[2])
axs[2].set_title("Reviews distribution by rating");

# %% [markdown]
# - After exclusion of positive reviews:

# %%
reviews = reviews[reviews.rating_id < 4].reset_index(drop=True)
print(reviews.shape)

fig, axs = plt.subplots(1, 3, figsize=(32, 5),  gridspec_kw={'width_ratios': [1, 2, 1]})
sns.countplot(x="year", hue="rating_id", data=reviews, ax=axs[0])
axs[0].set_title("Reviews distribution by year and rating")

sns.countplot(x="company", data=reviews, ax=axs[1])
axs[1].set_title("Reviews distribution by company")
axs[1].tick_params(axis="x", rotation=45);

sns.countplot(x="rating_id", data=reviews, ax=axs[2])
axs[2].set_title("Reviews distribution by rating");
# Out:
# (1275, 7)

# %% [markdown]
# - Distribution of reviews by month shows that the **number of reviews increased in first two years, then culminated at around 500 reviews per year.**

# %%
fig, axs = plt.subplots(1, 2, figsize=(32, 6), gridspec_kw={'width_ratios': [3, 1]})
sns.countplot(x="period", data=reviews, order=reviews.period.value_counts().index.sort_values(), ax=axs[0])
axs[0].set_title("Reviews count by month")
axs[0].tick_params(axis="x", rotation=45)
sns.countplot(x="year", data=reviews, ax=axs[1])
axs[1].set_title("Reviews count by year");

# %% [markdown]
# - Check the distribution of review title lengths to find out whether, by chance, reviewers did not enter the review into title. At the same time, check the distribution of review text lengths. The means and standard deviations are displayed in figure titles. **Figures show that the reviews are actually restricted to text field and the title can be effectively ignored.**

# %%
titles_list = [title for title in reviews.title.str.split()]
titles_lengths = pd.DataFrame(data={"length": [len(title) for title in titles_list]})

texts_list = [text for text in reviews.text.str.split()]
texts_lengths = pd.DataFrame(data={"length": [len(text) for text in texts_list]}).round(-1)

fig, axs = plt.subplots(1, 2, figsize=(32, 6), gridspec_kw={'width_ratios': [1, 3]})
sns.countplot(x="length", data=titles_lengths, ax=axs[0])
axs[0].set_title(f"Review title length distribution, mean: {titles_lengths.mean().values[0]:,.2f}, std: {titles_lengths.std().values[0]:,.2f}")
sns.countplot(x="length", data=texts_lengths, ax=axs[1])
axs[1].set_title(f"Review text length distribution, mean: {texts_lengths.mean().values[0]:,.2f}, std: {texts_lengths.std().values[0]:,.2f}");

# %% [markdown]
# ## 4. Reviews text preprocessing

# %% [markdown]
# - Define helper functions.

# %%
def tokenize(docs: pd.Series, min_len: int = 2, max_len: int = 30) -> List[List[str]]:
    return [simple_preprocess(doc, deacc=True, min_len=min_len, max_len=max_len) for doc in docs]
        
def lemmatize(tokenized_docs: List[List[str]], lemmatizer: Any) -> List[List[str]]:
    res = [[lemmatizer.lemmatize(lemmatizer.lemmatize(token, pos='v'), pos='n')
            for token in doc] for doc in tokenized_docs]
    return res

def add_trigram_phrases(lemmatized_docs: List[List[str]], min_count: int, threshold: int) -> List[List[str]]:
    bigram_model = Phrases(lemmatized_docs, min_count=min_count, threshold=threshold)
    trigram_model = Phrases(bigram_model[lemmatized_docs], min_count=min_count, threshold=threshold)
    res = list(trigram_model[bigram_model[lemmatized_docs]])
    return res
     
def filter_stopwords(phrased_docs: List[List[str]]) -> List[List[str]]:
    return [[token for token in doc if token not in STOPWORDS] for doc in phrased_docs]   
    
def filter_short_tokens(filtered_stopwords_docs: List[List[str]], min_len: int = 3) -> List[List[str]]:
    return [[token for token in doc if len(token) >= min_len] for doc in filtered_stopwords_docs]

# %% [markdown]
# - Apply consecutive tokenization, deaccentation, **WordNet** lemmatization, trigrams addition, stopwords filtering and short token filtering to each review text to produce processed documents, i.e. list of lists of tokens. We decided not to use stemmer, because we wanted to keep actual words in the dictionary instead of trimmed ones in order to easily interpret the predicted topics.

# %%
lemmatizer = WordNetLemmatizer()
docs = reviews.text

tokenized_docs = tokenize(docs, min_len=2, max_len=20)
lemmatized_docs = lemmatize(tokenized_docs, lemmatizer)
phrased_docs = add_trigram_phrases(lemmatized_docs, min_count=2, threshold=10)
filtered_stopwords_docs = filter_stopwords(phrased_docs)
processed_docs = filter_short_tokens(filtered_stopwords_docs, min_len=3)

# %% [markdown]
# ## 5. Gensim LDA model

# %% [markdown]
# - Define helper function.

# %%
def calc_coherence_metric(corpus, dictionary, topics, processed_docs, alpha, eta):
    lda_model = gensim.models.LdaModel(corpus=corpus,
                                       id2word=dictionary,
                                       num_topics=topics,
                                       passes=10,
                                       alpha=alpha,
                                       eta=eta,
                                       minimum_probability=0.1,
                                       random_state=10)
    
    coherence_model = CoherenceModel(model=lda_model,
                                     texts=processed_docs,
                                     corpus=corpus,
                                     coherence='c_v')
    
    return coherence_model.get_coherence()

# %% [markdown]
# - Plug tokenized documents into **gensim Dictionary** object and apply **filter_extremes function** filtering tokens that occur in less than 5 or in above 10% of documents. Then calculate **bag-of-words corpus** from the tokenized documents using the dictionary.

# %%
dictionary = gensim.corpora.Dictionary(processed_docs)
dictionary.filter_extremes(no_below=5, no_above=0.1, keep_n=100_000)

bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
corpus_size, dictionary_size = len(bow_corpus), len(dictionary)

print(f"Number of documents in the bow corpus is: {corpus_size}")
print(f"Number of words/tokens in the dictionary is: {dictionary_size}")
# Out:
# Number of documents in the bow corpus is: 1275
# Number of words/tokens in the dictionary is: 1403

# %% [markdown]
# - Check how the bag of words looks for a sample document selected from the corpus.

# %%
doc = 1000
bow_doc_x = bow_corpus[doc]

for i in range(len(bow_doc_x)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_x[i][0], dictionary[bow_doc_x[i][0]], bow_doc_x[i][1]))
# Out:
# Word 15 ("brighton") appears 1 time.
# Word 78 ("announce") appears 1 time.
# Word 107 ("bus") appears 1 time.
# Word 132 ("price") appears 1 time.
# Word 193 ("route") appears 1 time.
# Word 241 ("year") appears 1 time.
# Word 534 ("able_to") appears 1 time.
# Word 587 ("of_course") appears 1 time.
# Word 701 ("in_advance") appears 1 time.
# Word 771 ("cost") appears 1 time.
# Word 897 ("involve") appears 1 time.
# Word 990 ("a_long") appears 1 time.
# Word 1076 ("direct") appears 1 time.
# Word 1077 ("between_london") appears 1 time.
# Word 1120 ("highly") appears 1 time.
# Word 1183 ("so_many_time") appears 1 time.
# Word 1198 ("southern") appears 1 time.
# Word 1230 ("ongoing") appears 1 time.
# Word 1252 ("way_home") appears 1 time.

# %% [markdown]
# - Train the LDA model using bow_corpus and dictionary objects, using grid search method on the whole corpus. **Even though we've found the optimal alpha, eta and number of topics based on the optimisation of coherence metric, we decided to use a manually found combination of hyperparameters because our version proved to identify much more discriminated topics than that extracted from grid search.**

# %%
# min_topics, max_topics, step = 8, 13, 2

# topics_range = range(min_topics, max_topics, step)
# alphas = [0.1, 0.3, 0.5, 0.7, 1, 1.5] 
# etas = [0.1, 0.3, 0.5, 0.7, 1, 1.5]
# model_results = {'topics': [], 'alphas': [], 'etas': [], 'coherences': []}

# for topics in topics_range:
#     for alpha in alphas:
#         for eta in etas:
#             print(f"Params: topics: {topics}, alpha: {alpha}, eta: {eta}")
#             coherence = calc_coherence_metric(corpus=bow_corpus, 
#                                               dictionary=dictionary,
#                                               topics=topics, 
#                                               processed_docs=processed_docs,
#                                               alpha=alpha,
#                                               eta=eta)

#             model_results['topics'].append(topics)
#             model_results['alphas'].append(alpha)
#             model_results['etas'].append(eta)
#             model_results['coherences'].append(coherence)
                
# results = pd.DataFrame(model_results)

# %%
# results.sort_values(["coherences"], ascending=False).head(10)

# %% [markdown]
# - Our "manual" combination of hyperparameters with lower coherence score:

# %%
num_topics = 10

lda_model = gensim.models.LdaModel(corpus=bow_corpus, 
                                   num_topics=num_topics, 
                                   id2word=dictionary,                                    
                                   passes=10,
                                   alpha=0.7,
                                   eta=1,
                                   minimum_probability=0.1,
                                   random_state=10)

coherence_model = CoherenceModel(model=lda_model, texts=processed_docs, corpus=bow_corpus, coherence='c_v')
coherence = coherence_model.get_coherence()
print('Coherence Score: ', coherence)
# Out:
# Coherence Score:  0.2901808862749015

# %%
from gensim.models.wrappers.ldamallet import malletmodel2ldamodel
from gensim.models.wrappers import LdaMallet

num_topics = 6
mallet_path = "../mallet/bin/mallet"
lda_model = gensim.models.wrappers.LdaMallet(mallet_path,
                                             corpus=bow_corpus,
                                             alpha=1,
                                             workers=1,
                                             topic_threshold=0.01,
                                             random_seed=10,
                                             num_topics=num_topics,
                                             id2word=dictionary);

lda_model = malletmodel2ldamodel(lda_model)

coherence_model = CoherenceModel(model=lda_model, texts=processed_docs, corpus=bow_corpus, coherence='c_v')
coherence = coherence_model.get_coherence()
print('Coherence Score: ', coherence)
# Out:
# Mallet LDA: 6 topics, 3 topic bits, 111 topic mask
# Data loaded.
# max tokens: 180
# total tokens: 20288
# <10> LL/token: -7.73864
# <20> LL/token: -7.60955
# <30> LL/token: -7.53898
# <40> LL/token: -7.49645
#
# 0	0.16667	eurostar people change pay offer paris do_not experience board if_you due_to queue hour out_of problem complete purchase at_least trip spend
# 1	0.16667	company email customer_service phone reply customer complaint experience answer send provide check charge appal shock price issue leave contact start
# 2	0.16667	buy price pay company run virgin customer_service money people change cost station joke couldn bad commute pay_for southern half strike
# 3	0.16667	first_class virgin virgin_train carriage toilet food passenger dirty platform st_class miss leave home pay_for newcastle stand break table floor drink
# 4	0.16667	week gwr refund compensation month hour website southern late line wait min today return simply fare online virgin_train you_can problem
# 5	0.16667	station minute refund due_to customer passenger stop wait_for coach run money leave send fail advise reserve_seat catch car conductor late
#
# <50> LL/token: -7.47308
# <60> LL/token: -7.45502
# <70> LL/token: -7.4427
# <80> LL/token: -7.43378
# <90> LL/token: -7.42297
#
# 0	0.16667	eurostar people paris board pay experience change offer trip do_not queue purchase if_you passenger spend rude hour feel money no_one
# 1	0.16667	customer_service customer email complaint reply phone company send answer problem issue provide deal_with business shock virgin review request do_not check
# 2	0.16667	pay price buy people company website southern change southern_rail charge virgin commute bad station rail run money job explain strike
# 3	0.16667	first_class virgin virgin_train carriage platform toilet food leave dirty offer good edinburgh st_class home start line pay_for passenger newcastle cost
# 4	0.16667	refund gwr wait hour compensation customer_service virgin_train week change min late you_can tell_me claim worst hold return simply minute southern
# 5	0.16667	station run minute due_to late catch stop coach stand read company overcrowd passenger car terrible early leave customer reserve_seat happen
#
# <100> LL/token: -7.41292
# <110> LL/token: -7.41819
# <120> LL/token: -7.3998
# <130> LL/token: -7.38895
# <140> LL/token: -7.39096
#
# 0	0.16667	eurostar people pay paris offer charge change board purchase do_not trip fare price awful virgin_train if_you queue even_though hour due_to
# 1	0.16667	customer_service phone email customer complaint reply send company online answer response check do_not virgin problem deal_with speak complain request money
# 2	0.16667	pay company buy run customer virgin price southern website late southern_rail station change commute pay_for shock rail job strike worst
# 3	0.16667	first_class virgin carriage toilet food virgin_train line dirty poor guard st_class edinburgh newcastle good bad pay_for break offer table drink
# 4	0.16667	refund gwr compensation website change week hour customer_service hold virgin_train wait minute tell_me bother you_can southern late year previous arrive
# 5	0.16667	station minute passenger due_to run platform joke people provide catch stop leave out_of cost coach company cancellation overcrowd terrible arrive
#
# <150> LL/token: -7.37997
# <160> LL/token: -7.35773
# <170> LL/token: -7.36312
# <180> LL/token: -7.3658
# <190> LL/token: -7.3705
#
# 0	0.16667	eurostar pay change people charge experience paris trip purchase do_not rude even_though board queue complete awful spend offer price virgin_train
# 1	0.16667	customer_service phone email virgin complaint customer reply send answer response tell_me company check speak online do_not deal_with complain request number
# 2	0.16667	company southern price buy customer run pay bad southern_rail money worst station late commute start change job strike lose driver
# 3	0.16667	first_class carriage virgin virgin_train toilet food dirty couldn st_class passenger newcastle line offer leave extremely table drink break edinburgh floor
# 4	0.16667	refund website hour compensation hold money week pay_for virgin_train minute wait problem decide previous min bother cost receive no_one change
# 5	0.16667	station minute people passenger platform late gwr stop due_to run company catch provide good thing joke cancellation leave at_least overcrowd
#
# <200> LL/token: -7.3656
# <210> LL/token: -7.35583
# <220> LL/token: -7.361
# <230> LL/token: -7.355
# <240> LL/token: -7.36661
#
# 0	0.16667	eurostar pay experience change people paris charge rude board price awful leave if_you do_not queue virgin_train fare no_one min trip
# 1	0.16667	customer_service phone email complaint virgin reply customer send company online answer speak response receive check refund do_not tell_me deal_with request
# 2	0.16667	run southern customer company buy price pay southern_rail commute worst bad station late couldn job strike lose rail virgin start
# 3	0.16667	first_class carriage virgin toilet food virgin_train offer dirty reserve_seat st_class stand poor break edinburgh weekend extremely table newcastle drink floor
# 4	0.16667	refund website hour change virgin_train money hold return claim minute wait week due_to compensation previous gwr pay_for decide unable_to from_london
# 5	0.16667	station people passenger minute platform stop late gwr if_you catch due_to miss thing month leave coach avoid run overcrowd company
#
# <250> LL/token: -7.34312
# <260> LL/token: -7.3527
# <270> LL/token: -7.34785
# <280> LL/token: -7.33582
# <290> LL/token: -7.34196
#
# 0	0.16667	eurostar pay change experience people paris price if_you charge leave purchase trip queue rude awful situation wifi virgin_train date even_though
# 1	0.16667	customer_service phone email customer virgin complaint send reply online company tell_me answer check receive do_not speak write deal_with month review
# 2	0.16667	southern run buy company customer worst price pay line southern_rail late bad commute station couldn virgin start job strike rail
# 3	0.16667	first_class carriage virgin_train virgin food toilet offer dirty stand reserve_seat st_class good newcastle pay_for break weekend disgust extremely table drink
# 4	0.16667	refund website money hour problem week return virgin_train hold claim wait minute due_to cost change pay_for decide previous unable_to compensation
# 5	0.16667	station minute passenger late platform people gwr stop leave catch overcrowd miss due_to run thing do_not if_you hour provide at_least
#
# <300> LL/token: -7.34253
# <310> LL/token: -7.33352
# <320> LL/token: -7.3277
# <330> LL/token: -7.3384
# <340> LL/token: -7.32717
#
# 0	0.16667	eurostar pay people change paris rude if_you experience purchase charge company trip queue spend year offer terrible choice situation wifi
# 1	0.16667	customer_service phone email virgin customer complaint reply send company receive answer speak online do_not tell_me check deal_with refund week response
# 2	0.16667	price southern run company customer late worst buy experience start southern_rail change line commute bad job strike driver pay shock
# 3	0.16667	first_class carriage virgin virgin_train toilet food leave disgust buy reserve_seat st_class coach newcastle break edinburgh table drink offer pay_for people
# 4	0.16667	refund website money hold virgin_train claim hour pay_for problem cost minute return change decide compensation unable_to wait able_to person week
# 5	0.16667	station minute gwr platform passenger due_to stop late leave stand hour catch run arrive good miss thing morning wait guard
#
# <350> LL/token: -7.33463
# <360> LL/token: -7.32614
# <370> LL/token: -7.33781
# <380> LL/token: -7.33138
# <390> LL/token: -7.32823
#
# 0	0.16667	eurostar people pay charge purchase paris change rude experience price trip queue virgin_train do_not leave useless awful board explain even_though
# 1	0.16667	customer_service virgin phone email customer complaint reply send receive online do_not answer check tell_me company refund website compensation write deal_with
# 2	0.16667	southern company run price customer worst start southern_rail late commute bad line buy strike totally experience overcrowd rail people job
# 3	0.16667	first_class carriage virgin toilet food virgin_train passenger edinburgh stand coach reserve_seat st_class newcastle break weekend dirty table drink floor offer
# 4	0.16667	refund change website money return pay hour cost no_one claim pay_for buy_ticket hold line customer_service decide from_london minute station week
# 5	0.16667	station minute platform gwr stop late catch miss wait thing guard provide read an_hour passenger arrive run hour information half
#
# <400> LL/token: -7.32317
# <410> LL/token: -7.33729
# <420> LL/token: -7.31998
# <430> LL/token: -7.32696
# <440> LL/token: -7.31784
#
# 0	0.16667	eurostar people pay charge change paris rude money experience trip offer leave price queue spend useless terrible treat situation fare
# 1	0.16667	customer_service virgin phone email complaint reply customer send tell_me do_not receive online virgin_train buy answer compensation refund company due_to speak
# 2	0.16667	company run southern price worst customer experience bad start southern_rail people commute rail late job strike review joke buy franchise
# 3	0.16667	first_class carriage virgin virgin_train toilet food stand reserve_seat st_class passenger newcastle good edinburgh break weekend offer pay_for table drink floor
# 4	0.16667	refund change website pay return hour money problem cost claim if_you pay_for hold you_can buy_ticket station from_london customer_service date no_one
# 5	0.16667	station minute late passenger platform gwr stop leave catch hour due_to miss min thing board arrive read bus provide wait_for
#
# <450> LL/token: -7.31326
# <460> LL/token: -7.30655
# <470> LL/token: -7.30954
# <480> LL/token: -7.30128
# <490> LL/token: -7.30465
#
# 0	0.16667	eurostar people pay charge price experience paris rude change leave do_not queue awful money trip purchase even_though if_you terrible fare
# 1	0.16667	customer_service phone email complaint virgin reply customer send tell_me refund do_not buy company online receive compensation answer speak check response
# 2	0.16667	company southern run worst people customer start southern_rail price bad due_to commute job strike rail late pay franchise overcrowd line
# 3	0.16667	first_class virgin carriage virgin_train toilet food offer passenger edinburgh reserve_seat st_class stand couldn pay_for newcastle disgust table dirty drink break
# 4	0.16667	change refund website money if_you pay hold station claim date hour customer_service buy_ticket cost virgin_train pay_for problem no_one business week
# 5	0.16667	station minute late platform gwr stop min run due_to wait catch board arrive thing passenger guard absolutely read hour bus
#
# <500> LL/token: -7.31451
# <510> LL/token: -7.30956
# <520> LL/token: -7.33037
# <530> LL/token: -7.30693
# <540> LL/token: -7.30692
#
# 0	0.16667	eurostar people pay charge experience paris rude awful trip change queue purchase do_not money buy useless word situation wifi even_though
# 1	0.16667	customer_service refund phone email complaint reply customer send do_not virgin tell_me receive compensation answer online response company buy check deal_with
# 2	0.16667	company southern customer worst run people southern_rail line late commute joke bad strike rail experience price start horrible review fare
# 3	0.16667	first_class carriage toilet passenger virgin food offer edinburgh stand virgin_train coach reserve_seat st_class newcastle break weekend pay_for table drink floor
# 4	0.16667	change website virgin_train virgin money cost hour if_you problem pay station refund price you_can date pay_for minute site week decide
# 5	0.16667	station minute late platform stop run due_to gwr arrive hour miss leave wait catch min out_of month couldn guard return
#
# <550> LL/token: -7.31304
# <560> LL/token: -7.31409
# <570> LL/token: -7.31168
# <580> LL/token: -7.3163
# <590> LL/token: -7.31696
#
# 0	0.16667	eurostar people pay charge paris rude leave change purchase do_not trip experience queue spend situation awful wifi even_though they_will price
# 1	0.16667	customer_service phone email customer refund complaint reply send company virgin receive compensation do_not answer response tell_me week online deal_with check
# 2	0.16667	company southern run worst customer people southern_rail line absolutely due_to rail commute late strike job pay review bad conductor manchester
# 3	0.16667	first_class virgin carriage virgin_train toilet food offer passenger edinburgh reserve_seat stand st_class dirty coach break couldn newcastle disgust good pay_for
# 4	0.16667	change website money cost problem pay buy refund price station virgin_train virgin you_can date pay_for return buy_ticket offer site card
# 5	0.16667	station minute late hour platform gwr min stop catch board wait run passenger guard read miss due_to an_hour leave car
#
# <600> LL/token: -7.31758
# <610> LL/token: -7.30823
# <620> LL/token: -7.30444
# <630> LL/token: -7.30934
# <640> LL/token: -7.31985
#
# 0	0.16667	eurostar people pay charge experience change paris rude purchase price trip queue leave do_not if_you treat wifi virgin_train sit fare
# 1	0.16667	customer_service customer phone email refund complaint reply send company receive tell_me online compensation answer speak response do_not claim week deal_with
# 2	0.16667	company southern run worst people customer absolutely late southern_rail due_to commute bad line job strike rail pay joke this_company franchise
# 3	0.16667	first_class carriage passenger virgin toilet food virgin_train edinburgh stand coach reserve_seat st_class offer newcastle break weekend pay_for table drink floor
# 4	0.16667	virgin website change buy money price station refund problem you_can cost date hour pay_for pay offer if_you site minute buy_ticket
# 5	0.16667	station minute gwr platform late hour board catch stop due_to wait arrive month couldn miss min good run guard an_hour
#
# <650> LL/token: -7.30335
# <660> LL/token: -7.3
# <670> LL/token: -7.29559
# <680> LL/token: -7.30368
# <690> LL/token: -7.30467
#
# 0	0.16667	eurostar pay experience change price paris charge trip people purchase rude spend fare do_not queue terrible customer_service awful poor shock
# 1	0.16667	refund customer_service phone email customer complaint reply send compensation tell_me receive online do_not virgin_train answer response virgin company claim month
# 2	0.16667	company southern run people worst customer joke absolutely southern_rail start bad pay commute job strike rail if_you line late passenger
# 3	0.16667	first_class carriage passenger virgin toilet virgin_train stand food edinburgh reserve_seat offer st_class coach good newcastle dirty weekend leave disgust table
# 4	0.16667	buy website change virgin money problem price station hour you_can date pay_for refund customer_service virgin_train line from_london pay point site
# 5	0.16667	station late minute due_to gwr platform hour miss min week stop board catch leave guard arrive home wait_for couldn bus
#
# <700> LL/token: -7.31016
# <710> LL/token: -7.29713
# <720> LL/token: -7.30353
# <730> LL/token: -7.30558
# <740> LL/token: -7.31045
#
# 0	0.16667	eurostar pay change experience people paris price purchase charge queue from_london trip customer spend rude terrible money do_not situation wifi
# 1	0.16667	refund customer_service phone email complaint send reply customer tell_me receive compensation company answer speak online response claim do_not minute month
# 2	0.16667	company southern run worst people customer pay joke bad commute line review job strike rail experience absolutely drive horrible franchise
# 3	0.16667	first_class carriage passenger virgin toilet food virgin_train offer stand coach reserve_seat st_class edinburgh newcastle dirty board table drink pay_for floor
# 4	0.16667	buy virgin change website station price virgin_train hour problem return date money pay_for pay point you_can great offer if_you unable_to
# 5	0.16667	late station minute gwr platform min due_to hour week leave stop catch good start couldn wait arrive guard wait_for an_hour
#
# <750> LL/token: -7.30041
# <760> LL/token: -7.30013
# <770> LL/token: -7.29882
# <780> LL/token: -7.29176
# <790> LL/token: -7.30332
#
# 0	0.16667	eurostar change people experience purchase pay paris charge rude do_not trip fare terrible cost spend situation explain queue leave even_though
# 1	0.16667	customer_service refund phone email complaint reply send customer tell_me receive answer speak response compensation claim virgin_train company deal_with do_not month
# 2	0.16667	company southern run worst customer people bad line commute rail joke job strike pay absolutely awful drive start franchise overcrowd
# 3	0.16667	first_class virgin carriage food toilet passenger virgin_train edinburgh dirty stand reserve_seat st_class board coach leave people newcastle pay_for good table
# 4	0.16667	price buy website change virgin station pay money problem if_you virgin_train date hour pay_for you_can great buy_ticket return point site
# 5	0.16667	late station minute gwr due_to platform hour min stop today catch miss out_of arrive an_hour good wait run month at_least
#
# <800> LL/token: -7.29917
# <810> LL/token: -7.30384
# <820> LL/token: -7.31665
# <830> LL/token: -7.30255
# <840> LL/token: -7.29596
#
# 0	0.16667	eurostar people charge experience paris change pay do_not customer_service offer trip rude cost queue even_though spend virgin_train fare purchase from_london
# 1	0.16667	customer_service refund phone email complaint reply send customer virgin compensation tell_me receive company answer speak response claim do_not month minute
# 2	0.16667	company southern customer run people worst line southern_rail pay commute if_you absolutely job strike rail joke bad franchise excuse awful
# 3	0.16667	first_class carriage virgin virgin_train toilet food edinburgh passenger coach st_class good stand dirty newcastle reserve_seat break weekend poor people table
# 4	0.16667	change buy price pay website money station virgin pay_for problem date buy_ticket if_you great previous you_can return refuse_to line unable_to
# 5	0.16667	station late minute gwr platform hour min run today catch due_to board arrive miss out_of leave stop start passenger an_hour
#
# <850> LL/token: -7.29599
# <860> LL/token: -7.30508
# <870> LL/token: -7.29448
# <880> LL/token: -7.28971
# <890> LL/token: -7.30035
#
# 0	0.16667	eurostar change experience charge people paris price pay offer rude queue purchase spend leave trip fare terrible cost even_though year
# 1	0.16667	customer_service refund phone email complaint send reply customer tell_me do_not receive compensation virgin_train answer speak response company website claim online
# 2	0.16667	company southern people run customer worst absolutely late job strike commute overcrowd review bad pay experience start drive if_you franchise
# 3	0.16667	first_class carriage virgin passenger toilet food virgin_train offer dirty stand coach reserve_seat st_class edinburgh newcastle weekend disgust pay_for table drink
# 4	0.16667	buy change website pay virgin problem price line money date virgin_train station pay_for buy_ticket you_can return if_you great point refuse_to
# 5	0.16667	station due_to minute late hour platform gwr run min leave stop catch wait_for couldn arrive good miss read today an_hour
#
# <900> LL/token: -7.30152
# <910> LL/token: -7.2885
# <920> LL/token: -7.28452
# <930> LL/token: -7.29057
# <940> LL/token: -7.29172
#
# 0	0.16667	eurostar people change paris rude charge customer_service experience do_not pay trip cost spend year leave queue awful word situation offer
# 1	0.16667	refund customer_service phone email complaint send reply customer tell_me company virgin compensation receive do_not answer speak response claim virgin_train month
# 2	0.16667	company southern run customer worst people pay southern_rail absolutely commute if_you strike joke line review late experience overcrowd drive job
# 3	0.16667	first_class carriage passenger virgin toilet food virgin_train stand dirty edinburgh coach reserve_seat st_class newcastle break table drink extremely expect floor
# 4	0.16667	website change price buy pay virgin money station virgin_train pay_for problem you_can date leave buy_ticket great refuse_to unable_to site card
# 5	0.16667	station minute late platform due_to hour min today wait_for arrive catch gwr stop start miss board run an_hour bus couldn
#
# <950> LL/token: -7.29053
# <960> LL/token: -7.29504
# <970> LL/token: -7.28871
# <980> LL/token: -7.28963
# <990> LL/token: -7.29185
#
# 0	0.16667	eurostar change charge paris rude do_not experience people pay cost fare purchase spend terrible price completely from_london queue situation awful
# 1	0.16667	customer_service refund customer email phone complaint send reply virgin tell_me receive company compensation do_not response answer claim minute virgin_train speak
# 2	0.16667	company southern run people worst customer absolutely bad pay commute southern_rail strike job review line late money if_you drive rail
# 3	0.16667	first_class carriage passenger virgin toilet food stand virgin_train dirty coach reserve_seat st_class people edinburgh offer overcrowd newcastle leave extremely table
# 4	0.16667	buy pay change website problem virgin_train price date virgin pay_for money station hour great if_you trip refuse_to return unable_to site
# 5	0.16667	station late minute platform hour gwr week min due_to catch wait_for miss arrive couldn run stop today good wait leave
#
# <1000> LL/token: -7.29667
#
# Total time: 2 seconds
# Coherence Score:  0.2999860692523038

# %% [markdown]
# ## 6. Topics analysis

# %% [markdown]
# - Define helper functions.

# %%
def topics_in_documents_as_df(topics_in_documents_list, documents_df, num_topics, period_col="year"):
    res = pd.DataFrame(columns=range(num_topics))
    for i, document in enumerate(topics_in_documents_list):
        for topic_weight in document:
            res.loc[i, topic_weight[0]] = topic_weight[1]
        
    res = res.fillna(0)
    res["period"] = documents_df[period_col] 
    return res

def get_representative_docs_for_topic(topics_in_documents, documents_series, topic, n=10):
    indices = topics_in_documents.sort_values(by=topic, ascending=False)[topic].head(n).index 
    print(topics_in_documents.sort_values(by=topic, ascending=False)[topic].head(n))
    for i in range(n):
        print(documents_series[indices].tolist()[i], '\n')

# %% [markdown]
# - Display the identified topics and their most relevant words/tokens.

# %%
for i, topic in lda_model.show_topics(formatted=True, num_topics=num_topics, num_words=10):
    print(str(i) + ": "+ topic, '\n')
# Out:
# 0: 0.043*"eurostar" + 0.018*"charge" + 0.018*"people" + 0.017*"change" + 0.015*"paris" + 0.014*"rude" + 0.014*"experience" + 0.013*"price" + 0.012*"pay" + 0.012*"purchase"
#
# 1: 0.032*"customer_service" + 0.029*"refund" + 0.022*"email" + 0.020*"phone" + 0.020*"complaint" + 0.020*"customer" + 0.019*"reply" + 0.018*"send" + 0.016*"tell_me" + 0.015*"do_not"
#
# 2: 0.024*"company" + 0.021*"southern" + 0.017*"run" + 0.016*"people" + 0.016*"customer" + 0.013*"worst" + 0.012*"absolutely" + 0.011*"pay" + 0.010*"southern_rail" + 0.009*"strike"
#
# 3: 0.027*"first_class" + 0.022*"carriage" + 0.021*"passenger" + 0.019*"virgin" + 0.016*"toilet" + 0.015*"food" + 0.015*"virgin_train" + 0.012*"stand" + 0.011*"dirty" + 0.010*"coach"
#
# 4: 0.022*"change" + 0.022*"buy" + 0.020*"pay" + 0.020*"website" + 0.015*"problem" + 0.014*"virgin_train" + 0.013*"virgin" + 0.012*"station" + 0.011*"date" + 0.011*"pay_for"
#
# 5: 0.026*"station" + 0.020*"late" + 0.020*"minute" + 0.018*"hour" + 0.017*"due_to" + 0.016*"platform" + 0.014*"gwr" + 0.013*"min" + 0.013*"run" + 0.012*"week"

# %% [markdown]
# - Visualise identified topics using `pyLDAvis` package. **We can see that topics are well separated using PCA (principal component analysis).**

# %%
data = gensimvis.prepare(lda_model, bow_corpus, dictionary)
pyLDAvis.display(data)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el2888051399974673115687183327383"></div>
# <script type="text/javascript">
#
# var ldavis_el2888051399974673115687183327383_data = {"mdsDat": {"x": [0.14489448854674386, 0.2899125003969312, -0.04264457531489939, -0.16241793180276742, 0.05948145457913279, -0.2892259364051415], "y": [-0.019216040746744146, -0.0016249805662031226, -0.27735294978195824, 0.30491896187400425, 0.11186188829743472, -0.11858687907653344], "topics": [1, 2, 3, 4, 5, 6], "cluster": [1, 1, 1, 1, 1, 1], "Freq": [18.23301053079123, 17.48645280032618, 16.770411470540985, 16.733110785910608, 15.787606171640967, 14.98940824079002]}, "tinfo": {"Term": ["eurostar", "customer_service", "refund", "first_class", "station", "change", "email", "carriage", "customer", "southern", "complaint", "company", "reply", "buy", "website", "minute", "late", "phone", "virgin", "run", "pay", "people", "send", "passenger", "hour", "platform", "tell_me", "toilet", "charge", "do_not", "error", "when_ask", "address", "april", "phone_call", "form", "entitle_to", "order", "regard", "attempt", "member_of", "tell_me", "total", "make_sense", "ve_ever", "complain", "complaint", "deal_with", "after_week", "inform", "team", "call_them", "not_fair", "other_than", "process", "pas", "don_want", "email", "respond", "this_matter", "reply", "answer", "response", "claim", "contact", "number", "they_don", "give_up", "ring", "still_no", "policy", "confirm", "letter", "voucher", "ignore", "receive", "send", "refund", "phone", "compensation", "customer_service", "speak", "write", "check", "customer", "do_not", "online", "virgin", "company", "no_one", "request", "offer", "minute", "money", "website", "week", "general", "helpful", "early", "main", "bus", "chaos", "minute_late", "replacement", "inadequate", "afternoon", "member_of_staff", "wait_for", "destination", "tell_u", "we_arrive_at", "fin", "half", "off_peak", "pick", "hand", "rush", "get_off", "no_information", "laugh", "single", "horrendous", "suppose_to", "liverpool", "barely", "control", "platform", "min", "catch", "connection", "next_train", "terrible_service", "arrive_at", "announcement", "meet", "turn_up", "virgin_staff", "face", "notice", "instead_of", "short", "taxi", "usual", "strand", "break_down", "space", "get_home", "station", "late", "hour", "miss", "at_least", "minute", "today", "gwr", "due_to", "arrive", "stop", "week", "good", "board", "couldn", "wait", "run", "month", "driver", "start", "an_hour", "out_of", "morning", "national_rail", "load_of", "huge", "incompetence", "this_morning", "well_do", "snow", "stupid", "british_rail", "positive", "worst_company", "continue", "rout", "embarrass", "specific", "timetable", "so_many", "badly", "government", "every_single", "how_much", "school", "in_europe", "always_delay", "so_much", "in_fact", "why_do", "rate", "more_than", "rip_off", "southern", "strike", "drive", "franchise", "brighton", "excuse", "disgrace", "management", "high", "crap", "unacceptable", "their_customer", "commuter", "incompetent", "surprise", "most_of", "always_late", "frequent", "network", "every_day", "absolutely", "job", "southern_rail", "commute", "worst", "company", "run", "at_all", "customer", "rail", "people", "avoid", "review", "this_company", "bad", "pay", "route", "if_you", "money", "joke", "late", "start", "line", "gwr", "price", "york", "shoulder", "shrug", "menu", "sit_on", "toilet", "design", "proper", "carriage", "serve", "facility", "first_class", "attendant", "child", "my_family", "piece_of", "room", "sit_in", "pack", "would_not_recommend", "better_than", "free", "disable", "food", "first_class_ticket", "standard_class", "air_condition", "hot", "replace", "market", "dirty", "coach", "reserve_seat", "st_class", "newcastle", "drink", "table", "floor", "travel_with", "clean", "coffee", "sandwich", "glasgow", "bag", "virgin_east_coast", "breakfast", "stand_in", "area", "extremely", "passenger", "stand", "edinburgh", "virgin", "virgin_train", "disgust", "overcrowd", "bad", "leave", "offer", "pay_for", "poor", "expect", "people", "require", "hasn", "app", "collect", "site", "afford", "c ...

# %% [markdown]
# - Generate documents-topics "TF-IDF-like" matrix (dataframe) useful for further visualisations.

# %%
topics_in_documents_list = [lda_model[bow_corpus[i]] for i, _ in enumerate(bow_corpus)]
topics_in_documents = topics_in_documents_as_df(topics_in_documents_list, documents_df=reviews, num_topics=num_topics, period_col="year")

# %% [markdown]
# - Get top 10 representative documents for selected topic.

# %%
get_representative_docs_for_topic(topics_in_documents, documents_series=reviews.text, topic=6, n=5)
# Out:
# 568     0.943748
# 322     0.943748
# 1139    0.728568
# 670     0.724303
# 690     0.719654
# Name: 6, dtype: float64
# If you buy a ticket and choose to get an e-ticket you are no longer able to change the time/date of your train or get a refund. Even if you pay the admin fee. They hide this in their T&Cs. This wouldn't be acceptable in any other industry so don't know how they get away with this.
#
# If you buy a ticket and choose to get an e-ticket you are no longer able to change the time/date of your train or get a refund. Even if you pay the admin fee. They hide this in their T&Cs. This wouldn't be acceptable in any other industry so don't know how they get away with this.
#
# Every weekend it’s pretty impossible traveling to Swansea from London. Planned closure, crew shortage, staff not going to work... but they still charge you £90. Life is easy without competitors
#
# I've been frequently travelling between London and Paris for many years now. For pleasure as well as for business.
#
# On Eurostar from London to Paris, on time and friendly service. From Paris to London, we arrived 30 mins before departure as suggested. We were ushered into a queue with people with all sorts of timed tickets. They called out 7.13 train and were shocked to find at least 15 people still in the queue at 7.00. they made a poor effort of prioritising those with the earliest train time. We arrived to find we were already allocated to the next train with 5 mins to go before departure. No apology was offered and no real effort was made to get everyone on their allocated train even when we arrived on time. Sadly, Eurostar Paris were unable to fulfil the basic requirement of their service. Organising people to board the train.

# %% [markdown]
# - Display heatmap plot showing distribution of topics among documents, ordered by documents primary topic. From the colors of the heatmap, we can conclude that we have well separated primary topics in the majority of documents (only some documents are about more than one topic in).

# %%
heatmap_df = topics_in_documents[range(num_topics)]

fig, ax = plt.subplots(1, 1, figsize=(10, 20))
sns.heatmap(heatmap_df.loc[heatmap_df.idxmax(axis=1).sort_values().index], ax=ax);

# %% [markdown]
# - Display **primary topic distribution** (i.e. the most relevant topic for each document) plot over years. We see generally that most of the topics remained relevant for the whole period of 4 years. Regarding the question of whether the topics changed over years, this question could effectively be answered if we modelled each year separately and compared topics across years - this excercise was quite time demanding so I just outlined the idea/direction I would pursue. However, given the low number of observations and uncertainty in establishing the right labels for each identified topic, it would be relatively imprecise comparison or would require deeper analysis of underlying data.

# %%
primary_topics = pd.DataFrame(data={"topic": topics_in_documents[range(num_topics)].idxmax(axis=1), "period": topics_in_documents.period})
grouped = primary_topics.groupby(["period", "topic"]).agg(count=("topic", "count")).reset_index()
grouped["proportion"] = grouped["count"]/grouped.groupby("period")["count"].transform("sum")

fig, axs = plt.subplots(1, 2, figsize=(32, 5))
axs[0] = sns.countplot(x="period", hue="topic", data=primary_topics, ax=axs[0])
axs[0].set_title("Primary topic distribution over time");

axs[1] = sns.barplot(x="period", y="proportion", hue="topic", data=grouped, ax=axs[1])
axs[1].set_title("Primary topic distribution over time");
plt.legend(loc='upper left');
